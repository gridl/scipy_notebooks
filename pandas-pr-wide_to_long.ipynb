# %%
import pandas as pd
import numpy as np
from pandas import melt

# %%
def wide_to_long(df, stubnames, i, j):
    """
    Wide panel to long format. Less flexible but more user-friendly than melt.
    
    Parameters
    ----------
    df : DataFrame
    The wide-format DataFrame
    stubnames : list
    A list of stub names. The wide format variables are assumed to
    start with the stub names.
    i : str
    The name of the id variable.
    j : str
    The name of the subobservation variable.
    
    Returns
    -------
    DataFrame
    A DataFrame that contains each stub name as a variable as well as
    variables for i and j.
    
    Examples
    --------
    >>> import pandas as pd
    >>> import numpy as np
    >>> np.random.seed(123)
    >>> df = pd.DataFrame({"A1970" : {0 : "a", 1 : "b", 2 : "c"},
    ... "A1980" : {0 : "d", 1 : "e", 2 : "f"},
    ... "B1970" : {0 : 2.5, 1 : 1.2, 2 : .7},
    ... "B1980" : {0 : 3.2, 1 : 1.3, 2 : .1},
    ... "X" : dict(zip(range(3), np.random.randn(3)))
    ... })
    >>> df["id"] = df.index
    >>> df
    A1970 A1980 B1970 B1980 X
    0 a d 2.5 3.2 -1.085631
    1 b e 1.2 1.3 0.997345
    2 c f 0.7 0.1 0.282978
    >>> wide_to_long(df, ["A", "B"], i="id", j="year")
    X A B
    id year
    0 1970 -1.085631 a 2.5
    1 1970 0.997345 b 1.2
    2 1970 0.282978 c 0.7
    0 1980 -1.085631 d 3.2
    1 1980 0.997345 e 1.3
    2 1980 0.282978 f 0.1
    
    Notes
    -----
    All extra variables are treated as extra id variables. This simply uses
    `pandas.melt` under the hood, but is hard-coded to "do the right thing"
    in a typicaly case.
    """
    def get_var_names(df, regex):
        return df.filter(regex=regex).columns.tolist()

    def melt_stub(df, stub, i, j):
        varnames = get_var_names(df, "^"+stub)
        newdf = melt(df, id_vars=i, value_vars=varnames,
                         value_name=stub, var_name=j)
        newdf[j] = newdf[j].str.replace(stub, "").astype(int)
        return newdf

    id_vars = get_var_names(df, "^(?!%s)" % "|".join(stubnames))
    if i not in id_vars:
        id_vars += [i]

    stub = stubnames.pop(0)
    newdf = melt_stub(df, stub, id_vars, j)

    for stub in stubnames:
        new = melt_stub(df, stub, id_vars, j)
        newdf = newdf.merge(new, how="outer", on=id_vars + [j], copy=False)
    return newdf.set_index([i, j])

# %% [markdown]
# ## Test example of docstring

# %%
df = pd.DataFrame({"A1970" : {0 : "a", 1 : "b", 2 : "c"},
                   "A1980" : {0 : "d", 1 : "e", 2 : "f"},
                   "B1970" : {0 : 2.5, 1 : 1.2, 2 : .7},
                   "B1980" : {0 : 3.2, 1 : 1.3, 2 : .1},
                   "X" : dict(zip(range(3), np.random.randn(3)))
                   })

# %%
df["id"] = df.index

# %%
df
# Out:
#   A1970 A1980  B1970  B1980         X  id
# 0     a     d    2.5    3.2  1.337618   0
# 1     b     e    1.2    1.3  1.102580   1
# 2     c     f    0.7    0.1 -0.949247   2

# %%
wide_to_long(df, ["A", "B"], i="id", j="year")
# Out:
#                 X  A    B
# id year
# 0  1970  1.337618  a  2.5
# 1  1970  1.102580  b  1.2
# 2  1970 -0.949247  c  0.7
# 0  1980  1.337618  d  3.2
# 1  1980  1.102580  e  1.3
# 2  1980 -0.949247  f  0.1

# %% [markdown]
# ## Test example of stackoverflow

# %%
df_reshape_test = pd.DataFrame( {'location' : ['A', 'A', 'A', 'B', 'B', 'B'], 'dist_to_A' : [0, 0, 0, 50, 50, 50], 'dist_to_B' : [50, 50, 50, 0, 0, 0], 'location_var': [10, 10, 10, 14, 14, 14], 'ind_var': [3, 8, 10, 1, 3, 4]})

# %%
df_reshape_test
# Out:
#    dist_to_A  dist_to_B  ind_var location  location_var
# 0          0         50        3        A            10
# 1          0         50        8        A            10
# 2          0         50       10        A            10
# 3         50          0        1        B            14
# 4         50          0        3        B            14
# 5         50          0        4        B            14

# %%
wide_to_long(df_reshape_test, ["dist_to_"], i="index", j="AB")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-b0e2ecaf3b77> in <module>()
# ----> 1 wide_to_long(df_reshape_test, ["dist_to_"], i="index", j="AB")
#
# <ipython-input-2-1cd989ee8ebf> in wide_to_long(df, stubnames, i, j)
#      69
#      70     stub = stubnames.pop(0)
# ---> 71     newdf = melt_stub(df, stub, id_vars, j)
#      72
#      73     for stub in stubnames:
#
# <ipython-input-2-1cd989ee8ebf> in melt_stub(df, stub, i, j)
#      61         newdf = melt(df, id_vars=i, value_vars=varnames,
#      62                          value_name=stub, var_name=j)
# ---> 63         newdf[j] = newdf[j].str.replace(stub, "").astype(int)
#      64         return newdf
#      65
#
# c:\users\vdbosscj\scipy\pandas-joris\pandas\core\generic.pyc in astype(self, dtype, copy, raise_on_error)
#    1753
#    1754         mgr = self._data.astype(
# -> 1755             dtype, copy=copy, raise_on_error=raise_on_error)
#    1756         return self._constructor(mgr).__finalize__(self)
#    1757
#
# c:\users\vdbosscj\scipy\pandas-joris\pandas\core\internals.pyc in astype(self, *args, **kwargs)
#    2293
#    2294     def astype(self, *args, **kwargs):
# -> 2295         return self.apply('astype', *args, **kwargs)
#    2296
#    2297     def convert(self, *args, **kwargs):
#
# c:\users\vdbosscj\scipy\pandas-joris\pandas\core\internals.pyc in apply(self, f, *args, **kwargs)
#    2252
#    2253             else:
# -> 2254                 applied = getattr(blk, f)(*args, **kwargs)
#    2255
#    2256             if isinstance(applied, list):
#
# c:\users\vdbosscj\scipy\pandas-joris\pandas\core\internals.pyc in astype(self, dtype, copy, raise_on_error, values)
#     403     def astype(self, dtype, copy=False, raise_on_error=True, values=None):
#     404         return self._astype(dtype, copy=copy, raise_on_error=raise_on_error,
# --> 405                             values=values)
#     406
#     407     def _astype(self, dtype, copy=False, raise_on_error=True, values=None,
#
# c:\users\vdbosscj\scipy\pandas-joris\pandas\core\internals.pyc in _astype(self, dtype, copy, raise_on_error, values, klass)
#     420             # force the copy here
#     421             if values is None:
# --> 422                 values = com._astype_nansafe(self.values, dtype, copy=True)
#     423             newb = make_block(values, self.items, self.ref_items,
#     424                               ndim=self.ndim, placement=self._ref_locs,
#
# c:\users\vdbosscj\scipy\pandas-joris\pandas\core\common.pyc in _astype_nansafe(arr, dtype, copy)
#    2106     elif arr.dtype == np.object_ and np.issubdtype(dtype.type, np.integer):
#    2107         # work around NumPy brokenness, #1987
# -> 2108         return lib.astype_intsafe(arr.ravel(), dtype).reshape(arr.shape)
#    2109     elif issubclass(dtype.type, compat.string_types):
#    2110         return lib.astype_str(arr.ravel()).reshape(arr.shape)
#
# c:\users\vdbosscj\scipy\pandas-joris\pandas\lib.pyd in pandas.lib.astype_intsafe (pandas\lib.c:12435)()
#
# c:\users\vdbosscj\scipy\pandas-joris\pandas\lib.pyd in util.set_value_at (pandas\lib.c:48089)()
#
# ValueError: invalid literal for long() with base 10: 'A'
