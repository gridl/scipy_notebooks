# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '0.13.1-932-g1533480'

# %%
df = pd.DataFrame(np.random.randn(10,10))

# %%
df
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.077188 -1.453968 -1.767355 -2.128371 -0.806921  0.412588 -0.588839
# 1 -0.583976 -0.973327  1.352453 -0.585246 -0.790268  1.308357 -0.631113
# 2 -0.566819  0.744229 -0.995482  0.583275  0.826578 -0.023262 -1.731514
# 3  0.031625  0.755326 -1.790732  1.082566 -0.100892 -0.962388  0.713899
# 4 -0.344861 -0.201941 -1.824489 -1.235177  0.761041  0.252299  1.607193
# 5  0.486160 -0.708256  0.808962  0.712726 -1.053172  0.576331 -1.009143
# 6  0.703093  0.738568 -0.134528  0.975968 -1.184547  1.566535 -1.061575
# 7  0.229482 -1.043245  0.762085 -2.434543 -1.921825 -0.855031 -0.601185
# 8  0.225594 -0.470578 -0.333155 -1.178057  0.170454  2.093166  0.162607
# 9  1.627732 -1.944585 -1.034432 -1.232890  0.099959  0.179352  0.981698
#
#           7         8         9
# 0  0.325630  0.078272  0.805554
# 1 -0.220643 -0.398214  0.189901
# 2  0.454618 -0.620292 -0.506806
# 3 -1.048930 -0.609715 -1.406356
# 4 -0.914284 -0.346587 -1.421024
# 5 -0.864597 -1.188099 -1.042288
# 6 -0.678347 -0.415908 -0.810494
# 7  0.739852 -0.160526 -0.532549
# 8  0.570095  1.394783  2.333259
# 9  0.172062 -0.707392 -1.813149

# %%
pd.options.display.max_rows = 5

# %%
df
# Out:
#                   0         1         2         3         4         5  \
# 0         -0.077188 -1.453968 -1.767355 -2.128371 -0.806921  0.412588
# 1         -0.583976 -0.973327  1.352453 -0.585246 -0.790268  1.308357
# .         ......... .........  ........ ......... .........  ........
# 8          0.225594 -0.470578 -0.333155 -1.178057  0.170454  2.093166
# 9          1.627732 -1.944585 -1.034432 -1.232890  0.099959  0.179352
#
#                   6         7         8         9
# 0         -0.588839  0.325630  0.078272  0.805554
# 1         -0.631113 -0.220643 -0.398214  0.189901
# .         ......... ......... .........  ........
# 8          0.162607  0.570095  1.394783  2.333259
# 9          0.981698  0.172062 -0.707392 -1.813149
#
# [10 rows x 10 columns]

# %%
pd.options.display.max_rows = 7

# %%
df
# Out:
#                   0         1         2         3         4         5  \
# 0         -0.077188 -1.453968 -1.767355 -2.128371 -0.806921  0.412588
# 1         -0.583976 -0.973327  1.352453 -0.585246 -0.790268  1.308357
# 2         -0.566819  0.744229 -0.995482  0.583275  0.826578 -0.023262
# .         .........  ........ .........  ........  ........ .........
# 7          0.229482 -1.043245  0.762085 -2.434543 -1.921825 -0.855031
# 8          0.225594 -0.470578 -0.333155 -1.178057  0.170454  2.093166
# 9          1.627732 -1.944585 -1.034432 -1.232890  0.099959  0.179352
#
#                   6         7         8         9
# 0         -0.588839  0.325630  0.078272  0.805554
# 1         -0.631113 -0.220643 -0.398214  0.189901
# 2         -1.731514  0.454618 -0.620292 -0.506806
# .         .........  ........ ......... .........
# 7         -0.601185  0.739852 -0.160526 -0.532549
# 8          0.162607  0.570095  1.394783  2.333259
# 9          0.981698  0.172062 -0.707392 -1.813149
#
# [10 rows x 10 columns]

# %%
pd.options.display.max_rows = 8

# %%
df
# Out:
#                   0         1         2         3         4         5  \
# 0         -0.077188 -1.453968 -1.767355 -2.128371 -0.806921  0.412588
# 1         -0.583976 -0.973327  1.352453 -0.585246 -0.790268  1.308357
# 2         -0.566819  0.744229 -0.995482  0.583275  0.826578 -0.023262
# 3          0.031625  0.755326 -1.790732  1.082566 -0.100892 -0.962388
# .          ........  ........ .........  ........ ......... .........
# 6          0.703093  0.738568 -0.134528  0.975968 -1.184547  1.566535
# 7          0.229482 -1.043245  0.762085 -2.434543 -1.921825 -0.855031
# 8          0.225594 -0.470578 -0.333155 -1.178057  0.170454  2.093166
# 9          1.627732 -1.944585 -1.034432 -1.232890  0.099959  0.179352
#
#                   6         7         8         9
# 0         -0.588839  0.325630  0.078272  0.805554
# 1         -0.631113 -0.220643 -0.398214  0.189901
# 2         -1.731514  0.454618 -0.620292 -0.506806
# 3          0.713899 -1.048930 -0.609715 -1.406356
# .          ........ ......... ......... .........
# 6         -1.061575 -0.678347 -0.415908 -0.810494
# 7         -0.601185  0.739852 -0.160526 -0.532549
# 8          0.162607  0.570095  1.394783  2.333259
# 9          0.981698  0.172062 -0.707392 -1.813149
#
# [10 rows x 10 columns]

# %% [markdown]
# ### For the columns it is correct:

# %%
pd.options.display.max_rows = 60

# %%
pd.options.display.max_columns = 5

# %%
df
# Out:
#           0         1    ...            8         9
# 0 -1.277398  0.123930    ...    -2.027021  1.853041
# 1 -0.062937 -1.174654    ...     0.305154  1.134382
# 2 -0.294352 -0.642515    ...    -1.131197 -1.053782
# 3  0.317469  1.010120    ...     0.236574 -0.127202
# 4 -0.514724 -0.231518    ...    -0.306783 -0.522492
# 5 -0.722990 -0.462122    ...    -1.639068 -1.243736
# 6  1.094079  1.949794    ...     0.512170  0.199890
# 7  0.800593  1.266304    ...     2.001745 -1.341659
# 8  0.839586 -0.497199    ...    -0.282139 -0.747837
# 9 -1.381082 -0.612229    ...     0.195801 -0.146526
#
# [10 rows x 10 columns]

# %%
pd.options.display.max_columns = 20

# %%
df = pd.util.testing.makeMixedDataFrame()

# %%
df
# Out:
#    A  B     C          D
# 0  0  0  foo1 2009-01-01
# 1  1  1  foo2 2009-01-02
# 2  2  0  foo3 2009-01-05
# 3  3  1  foo4 2009-01-06
# 4  4  0  foo5 2009-01-07

# %%
pd.options.display.max_columns = 2

# %%
df
# Out:
#    A ...          D
# 0  0 ... 2009-01-01
# 1  1 ... 2009-01-02
# 2  2 ... 2009-01-05
# 3  3 ... 2009-01-06
# 4  4 ... 2009-01-07
#
# [5 rows x 4 columns]

# %% [markdown]
# ### Here also something strange

# %%
pd.options.display.max_rows = 2

# %%
df
# Out:
#     A ...          D
# 0   0 ... 2009-01-01
# .   . ... ..........
# 4   4 ... 2009-01-07
#
# [5 rows x 4 columns]

# %%
pd.options.display.max_rows = 60
pd.options.display.max_columns = 20

# %%
df = pd.util.testing.makeMissingCustomDataframe(10000,100)

# %% [markdown]
# ### Also here the location is not correct

# %%
df
# Out:
# C0          C_l0_g0  C_l0_g1  C_l0_g2  C_l0_g3  C_l0_g4  C_l0_g5  C_l0_g6  \
# R0
# R_l0_g0        R0C0     R0C1     R0C2      NaN     R0C4      NaN     R0C6
# R_l0_g1        R1C0     R1C1     R1C2      NaN     R1C4     R1C5     R1C6
# R_l0_g2        R2C0     R2C1     R2C2     R2C3     R2C4     R2C5     R2C6
# R_l0_g3        R3C0     R3C1     R3C2     R3C3     R3C4     R3C5     R3C6
# R_l0_g4        R4C0     R4C1     R4C2     R4C3     R4C4     R4C5     R4C6
# R_l0_g5        R5C0     R5C1     R5C2      NaN     R5C4     R5C5     R5C6
# R_l0_g6        R6C0      NaN     R6C2     R6C3     R6C4     R6C5      NaN
# R_l0_g7         NaN     R7C1     R7C2     R7C3     R7C4     R7C5     R7C6
# R_l0_g8        R8C0     R8C1     R8C2     R8C3     R8C4      NaN     R8C6
# R_l0_g9        R9C0     R9C1     R9C2     R9C3     R9C4     R9C5     R9C6
# R_l0_g10      R10C0    R10C1    R10C2    R10C3    R10C4    R10C5    R10C6
# R_l0_g11      R11C0    R11C1    R11C2    R11C3    R11C4    R11C5    R11C6
# R_l0_g12      R12C0    R12C1    R12C2    R12C3    R12C4    R12C5    R12C6
# R_l0_g13      R13C0    R13C1    R13C2    R13C3    R13C4    R13C5    R13C6
# R_l0_g14      R14C0    R14C1    R14C2    R14C3      NaN    R14C5    R14C6
# R_l0_g15      R15C0    R15C1    R15C2    R15C3    R15C4    R15C5    R15C6
# R_l0_g16      R16C0    R16C1    R16C2    R16C3    R16C4    R16C5    R16C6
# R_l0_g17      R17C0      NaN    R17C2      NaN    R17C4    R17C5    R17C6
# R_l0_g18      R18C0    R18C1    R18C2    R18C3    R18C4    R18C5      NaN
# R_l0_g19      R19C0    R19C1    R19C2      NaN    R19C4    R19C5    R19C6
# R_l0_g20      R20C0    R20C1    R20C2    R20C3    R20C4    R20C5    R20C6
# R_l0_g21      R21C0    R21C1    R21C2    R21C3    R21C4    R21C5    R21C6
# R_l0_g22      R22C0    R22C1    R22C2    R22C3    R22C4    R22C5    R22C6
# R_l0_g23      R23C0    R23C1    R23C2    R23C3    R23C4    R23C5      NaN
# R_l0_g24      R24C0    R24C1    R24C2    R24C3    R24C4      NaN    R24C6
# R_l0_g25        NaN    R25C1    R25C2    R25C3    R25C4    R25C5    R25C6
# R_l0_g26      R26C0    R26C1    R26C2    R26C3    R26C4      NaN    R26C6
# R_l0_g27      R27C0    R27C1    R27C2    R27C3    R27C4      NaN    R27C6
# R_l0_g28      R28C0    R28C1    R28C2    R28C3    R28C4    R28C5    R28C6
# R_l0_g29      R29C0    R29C1    R29C2    R29C3    R29C4    R29C5    R29C6
# ........      .....    .....    .....    .....    .....    .....    .....
# R_l0_g9970  R9970C0  R9970C1  R9970C2  R9970C3  R9970C4  R9970C5      NaN
# R_l0_g9971  R9971C0  R9971C1  R9971C2  R9971C3  R9971C4  R9971C5  R9971C6
# R_l0_g9972  R9972C0  R9972C1  R9972C2  R9972C3  R9972C4      NaN  R9972C6
# R_l0_g9973  R9973C0      NaN      NaN  R9973C3  R9973C4  R9973C5  R9973C6
# R_l0_g9974  R9974C0  R9974C1  R9974C2  R9974C3  R9974C4  R9974C5  R9974C6
# R_l0_g9975  R9975C0  R9975C1  R9975C2  R9975C3  R9975C4  R9975C5  R9975C6
# R_l0_g9976      NaN  R9976C1      NaN  R9976C3      NaN      NaN  R9976C6
# R_l0_g9977  R9977C0  R9977C1  R9977C2  R9977C3  R9977C4  R9977C5  R9977C6
# R_l0_g9978  R9978C0  R9978C1  R9978C2  R9978C3  R9978C4  R9978C5  R9978C6
# R_l0_g9979  R9979C0  R9979C1  R9979C2  R9979C3  R9979C4  R9979C5  R9979C6
# R_l0_g9980  R9980C0  R9980C1      NaN      NaN  R9980C4  R9980C5  R9980C6
# R_l0_g9981      NaN  R9981C1  R9981C2      NaN  R9981C4      NaN  R9981C6
# R_l0_g9982  R9982C0  R9982C1  R9982C2  R9982C3  R9982C4  R9982C5  R9982C6
# R_l0_g9983  R9983C0  R9983C1  R9983C2  R9983C3  R9983C4  R9983C5  R9983C6
# R_l0_g9984  R9984C0  R9984C1  R9984C2  R9984C3  R9984C4  R9984C5  R9984C6
# R_l0_g9985  R9985C0  R9985C1  R9985C2      NaN  R9985C4      NaN  R9985C6
# R_l0_g9986  R9986C0  R9986C1  R9986C2  R9986C3  R9986C4  R9986C5  R9986C6
# R_l0_g9987      NaN  R9987C1  R9987C2  R9987C3  R9987C4      NaN  R9987C6
# R_l0_g9988  R9988C0  R9988C1  R9988C2  R9988C3  R9988C4      NaN  R9988C6
# R_l0_g9989  R9989C0  R9989C1  R9989C2  R9989C3  R9989C4  R9989C5  R9989C6
# R_l0_g9990  R9990C0  R9990C1  R9990C2  R9990C3  R9990C4  R9990C5  R9990C6
# R_l0_g9991  R9991C0  R9991C1  R9991C2      NaN  R9991C4  R9991C5  R9991C6
# R_l0_g9992  R9992C0  R9992C1  R9992C2  R9992C3  R9992C4  R9992C5  R9992C6
# R_l0_g9993  R9993C0  R9993C1  R9993C2  R9993C3      NaN  R9993C5  R9993C6
# R_l0_g9994  R9994C0  R9994C1  R9994C2  R9994C3  R9994C4  R9994C5  R9994C6
# R_l0_g9995  R9995C0  R9995C1  R9995C2  R9995C3      NaN  R9995C5      NaN
# R_l0_g9996  R9996C0  R9996C1  R9996C2  R9996C3  R9996C4  R9996C5  R9996C6
# R_l0_g9997  R9997C0  R9997C1  R9997C2  R9997C3  R9997C4  R9997C5  R9997C6
# R_l0_g9998  R9998C0  R9998C1  R9998C2  R9998C3  R9998C4  R9998C5  R9998C6
# R_l0_g9999  R9999C0  R9999C1  R9999C2  R9999C3  R9999C4  R9999C5  R9999C6
#
# C0          C_l0_g7  C_l0_g8  C_l0_g9   ...     C_l0_g90  C_l0_g91  C_l0_g92  \
# R0                                      ...
# R_l0_g0        R0C7     R0C8     R0C9   ...        R0C90     R0C91     R0C92
# R_l0_g1        R1C7     R1C8     R1C9   ...        R1C90     R1C91     R1C92
# R_l0_g2        R2C7     R2C8     R2C9   ...        R2C90     R2C91       NaN
# R_l0_g3        R3C7     R3C8     R3C9   ...        R3C90     R3C91     R3C92
# R_l0_g4        R4C7     R4C8     R4C9   ...        R4C90     R4C91       NaN
# R_l0_g5        R5C7     R5C8     R5C9   ...        R5C90     R5C91     R5C92
# R_l0_g6        R6C7     R6C8     R6C9   ...        R6C90     R6C91       NaN
# R_l0_g7        R7C7     R7C8     R7C9   ...        R7C90     R7C91     R7C92
# R_l0_g8        R8C7     R8C8     R8C9   ...        R8C90     R8C91     R8C92
# R_l0_g9        R9C7     R9C8     R9C9   ...        R9C90     R9C91     R9C92
# R_l0_g10      R10C7    R10C8    R10C9   ...       R10C90    R10C91    R10C92
# R_l0_g11      R11C7    R11C8    R11C9   ...       R11C90    R11C91    R11C92
# R_l0_g12      R12C7    R12C8    R12C9   ...       R12C90    R12C91    R12C92
# R_l0_g13      R13C7    R13C8    R13C9   ...       R13C90    R13C91    R13C92
# R_l0_g14      R14C7    R14C8    R14C9   ...       R14C90    R14C91    R14C92
# R_l0_g15      R15C7    R15C8    R15C9   ...       R15C90    R15C91    R15C92
# R_l0_g16        NaN    R16C8    R16C9   ...       R16C90    R16C91    R16C92
# R_l0_g17      R17C7    R17C8    R17C9   ...       R17C90    R17C91    R17C92
# R_l0_g18        NaN    R18C8    R18C9   ...          NaN    R18C91    R18C92
# R_l0_g19      R19C7    R19C8    R19C9   ...       R19C90    R19C91       NaN
# R_l0_g20        NaN    R20C8    R20C9   ...       R20C90    R20C91    R20C92
# R_l0_g21      R21C7    R21C8    R21C9   ...       R21C90       NaN    R21C92
# R_l0_g22      R22C7    R22C8      NaN   ...       R22C90    R22C91    R22C92
# R_l0_g23      R23C7    R23C8    R23C9   ...       R23C90    R23C91    R23C92
# R_l0_g24        NaN    R24C8    R24C9   ...       R24C90    R24C91    R24C92
# R_l0_g25      R25C7    R25C8    R25C9   ...          NaN    R25C91    R25C92
# R_l0_g26      R26C7    R26C8    R26C9   ...       R26C90    R26C91    R26C92
# R_l0_g27      R27C7    R27C8    R27C9   ...       R27C90    R27C91    R27C92
# R_l0_g28        NaN    R28C8    R28C9   ...       R28C90    R28C91    R28C92
# R_l0_g29      R29C7    R29C8    R29C9   ...       R29C90    R29C91    R29C92
# ........        ...    .....    .....   ...       ......    ......    ......
# R_l0_g9970  R9970C7  R9970C8  R9970C9   ...     R9970C90  R9970C91  R9970C92
# R_l0_g9971  R9971C7  R9971C8      NaN   ...     R9971C90  R9971C91       NaN
# R_l0_g9972  R9972C7  R9972C8  R9972C9   ...     R9972C90  R9972C91  R9972C92
# R_l0_g9973  R9973C7  R9973C8      NaN   ...     R9973C90  R9973C91  R9973C92
# R_l0_g9974  R9974C7      NaN  R9974C9   ...     R9974C90       NaN  R9974C92
# R_l0_g9975  R9975C7  R9975C8  R9975C9   ...     R9975C90  R9975C91  R9975C92
# R_l0_g9976  R9976C7  R9976C8  R9976C9   ...     R9976C90  R9976C91  R9976C92
# R_l0_g9977  R9977C7  R9977C8  R9977C9   ...     R9977C90  R9977C91  R9977C92
# R_l0_g9978  R9978C7  R9978C8  R9978C9   ...     R9978C90  R9978C91  R9978C92
# R_l0_g9979  R9979C7  R9979C8  R9979C9   ...     R9979C90  R9979C91  R9979C92
# R_l0_g9980  R9980C7  R9980C8  R9980C9   ...     R9980C90  R9980C91       NaN
# R_l0_g9981  R9981C7      NaN  R9981C9   ...     R9981C90  R9981C91       NaN
# R_l0_g9982  R9982C7  R9982C8  R9982C9   ...     R9982C90  R9982C91  R9982C92
# R_l0_g9983  R9983C7  R9983C8  R9983C9   ...     R9983C90  R9983C91       NaN
# R_l0_g9984  R9984C7  R9984C8  R9984C9   ...     R9984C90       NaN       NaN
# R_l0_g9985  R9985C7  R9985C8      NaN   ...     R9985C90  R9985C91       NaN
# R_l0_g9986  R9986C7  R9986C8  R9986C9   ...     R9986C90  R9986C91  R9986C92
# R_l0_g9987  R9987C7  R9987C8  R9987C9   ...     R9987C90  R9987C91  R9987C92
# R_l0_g9988  R9988C7  R9988C8  R9988C9   ...     R9988C90  R9988C91  R9988C92
# R_l0_g9989  R9989C7  R9989C8  R9989C9   ...     R9989C90  R9989C91  R9989C92
# R_l0_g9990  R9990C7  R9990C8  R9990C9   ...     R9990C90  R9990C91  R9990C92
# R_l0_g9991  R9991C7  R9991C8  R9991C9   ...     R9991C90  R9991C91  R9991C92
# R_l0_g9992  R9992C7  R9992C8  R9992C9   ...     R9992C90  R9992C91       NaN
# R_l0_g9993  R9993C7  R9993C8  R9993C9   ...          NaN  R9993C91       NaN
# R_l0_g9994  R9994C7      NaN  R9994C9   ...     R9994C90  R9994C91  R9994C92
# R_l0_g9995  R9995C7  R9995C8  R9995C9   ...     R9995C90  R9995C91  R9995C92
# R_l0_g9996  R9996C7  R9996C8  R9996C9   ...     R9996C90  R9996C91  R9996C92
# R_l0_g9997  R9997C7      NaN  R9997C9   ...     R9997C90  R9997C91  R9997C92
# R_l0_g9998  R9998C7  R9998C8  R9998C9   ...     R9998C90  R9998C91  R9998C92
# R_l0_g9999  R9999C7  R9999C8  R9999C9   ...     R9999C90  R9999C91  R9999C92
#
# C0          C_l0_g93  C_l0_g94  C_l0_g95  C_l0_g96  C_l0_g97  C_l0_g98  \
# R0
# R_l0_g0        R0C93     R0C94     R0C95     R0C96     R0C97     R0C98
# R_l0_g1        R1C93     R1C94     R1C95     R1C96     R1C97     R1C98
# R_l0_g2        R2C93     R2C94     R2C95     R2C96     R2C97     R2C98
# R_l0_g3        R3C93     R3C94       NaN     R3C96     R3C97     R3C98
# R_l0_g4        R4C93     R4C94     R4C95     R4C96     R4C97     R4C98
# R_l0_g5        R5C93     R5C94     R5C95     R5C96     R5C97     R5C98
# R_l0_g6        R6C93       NaN     R6C95     R6C96     R6C97     R6C98
# R_l0_g7        R7C93     R7C94     R7C95     R7C96     R7C97     R7C98
# R_l0_g8          NaN       NaN     R8C95     R8C96     R8C97     R8C98
# R_l0_g9          NaN     R9C94     R9C95     R9C96     R9C97     R9C98
# R_l0_g10      R10C93    R10C94    R10C95    R10C96    R10C97    R10C98
# R_l0_g11      R11C93    R11C94    R11C95    R11C96    R11C97    R11C98
# R_l0_g12      R12C93    R12C94    R12C95    R12C96    R12C97    R12C98
# R_l0_g13         NaN    R13C94    R13C95    R13C96    R13C97    R13C98
# R_l0_g14      R14C93    R14C94    R14C95    R14C96    R14C97    R14C98
# R_l0_g15      R15C93    R15C94    R15C95    R15C96    R15C97    R15C98
# R_l0_g16      R16C93       NaN    R16C95    R16C96    R16C97    R16C98
# R_l0_g17      R17C93    R17C94    R17C95    R17C96    R17C97    R17C98
# R_l0_g18      R18C93       NaN    R18C95    R18C96    R18C97    R18C98
# R_l0_g19      R19C93    R19C94    R19C95    R19C96    R19C97    R19C98
# R_l0_g20      R20C93       NaN    R20C95    R20C96    R20C97    R20C98
# R_l0_g21         NaN    R21C94    R21C95    R21C96    R21C97    R21C98
# R_l0_g22      R22C93    R22C94       NaN    R22C96    R22C97    R22C98
# R_l0_g23      R23C93    R23C94    R23C95    R23C96    R23C97    R23C98
# R_l0_g24      R24C93    R24C94    R24C95    R24C96    R24C97    R24C98
# R_l0_g25         NaN    R25C94    R25C95    R25C96    R25C97    R25C98
# R_l0_g26      R26C93       NaN    R26C95    R26C96    R26C97    R26C98
# R_l0_g27      R27C93    R27C94    R27C95    R27C96    R27C97    R27C98
# R_l0_g28      R28C93    R28C94    R28C95    R28C96    R28C97    R28C98
# R_l0_g29      R29C93    R29C94    R29C95    R29C96    R29C97    R29C98
# ........      ......    ......    ......    ......    ......    ......
# R_l0_g9970  R9970C93  R9970C94  R9970C95  R9970C96  R9970C97  R9970C98
# R_l0_g9971  R9971C93       NaN  R9971C95  R9971C96  R9971C97  R9971C98
# R_l0_g9972  R9972C93  R9972C94  R9972C95  R9972C96  R9972C97  R9972C98
# R_l0_g9973       NaN  R9973C94  R9973C95  R9973C96  R9973C97  R9973C98
# R_l0_g9974  R9974C93  R9974C94  R9974C95  R9974C96  R9974C97  R9974C98
# R_l0_g9975  R9975C93  R9975C94  R9975C95  R9975C96  R9975C97  R9975C98
# R_l0_g9976  R9976C93  R9976C94  R9976C95  R9976C96  R9976C97  R9976C98
# R_l0_g9977  R9977C93  R9977C94  R9977C95  R9977C96  R9977C97  R9977C98
# R_l0_g9978  R9978C93  R9978C94  R9978C95  R9978C96  R9978C97  R9978C98
# R_l0_g9979  R9979C93  R9979C94  R9979C95  R9979C96  R9979C97  R9979C98
# R_l0_g9980  R9980C93  R9980C94  R9980C95  R9980C96  R9980C97  R9980C98
# R_l0_g9981  R9981C93       NaN  R9981C95  R9981C96  R9981C97  R9981C98
# R_l0_g9982  R9982C93  R9982C94  R9982C95  R9982C96  R9982C97  R9982C98
# R_l0_g9983  R9983C93  R9983C94  R9983C95  R9983C96  R9983C97  R9983C98
# R_l0_g9984  R9984C93  R9984C94  R9984C95  R9984C96  R9984C97  R9984C98
# R_l0_g9985  R9985C93  R9985C94  R9985C95  R9985C96  R9985C97  R9985C98
# R_l0_g9986  R9986C93  R9986C94  R9986C95  R9986C96  R9986C97  R9986C98
# R_l0_g9987  R9987C93  R9987C94  R9987C95  R9987C96  R9987C97  R9987C98
# R_l0_g9988  R9988C93  R9988C94  R9988C95  R9988C96  R9988C97  R9988C98
# R_l0_g9989  R9989C93  R9989C94  R9989C95  R9989C96  R9989C97  R9989C98
# R_l0_g9990  R9990C93  R9990C94  R9990C95  R9990C96  R9990C97  R9990C98
# R_l0_g9991  R9991C93  R9991C94  R9991C95  R9991C96  R9991C97  R9991C98
# R_l0_g9992  R9992C93  R9992C94  R9992C95  R9992C96  R9992C97  R9992C98
# R_l0_g9993  R9993C93  R9993C94  R9993C95  R9993C96  R9993C97  R9993C98
# R_l0_g9994  R9994C93  R9994C94  R9994C95  R9994C96  R9994C97  R9994C98
# R_l0_g9995  R9995C93  R9995C94  R9995C95  R9995C96  R9995C97  R9995C98
# R_l0_g9996  R9996C93  R9996C94  R9996C95  R9996C96  R9996C97  R9996C98
# R_l0_g9997  R9997C93  R9997C94  R9997C95  R9997C96  R9997C97  R9997C98
# R_l0_g9998  R9998C93  R9998C94  R9998C95  R9998C96  R9998C97  R9998C98
# R_l0_g9999  R9999C93  R9999C94  R9999C95  R9999C96  R9999C97  R9999C98
#
# C0          C_l0_g99
# R0
# R_l0_g0        R0C99
# R_l0_g1        R1C99
# R_l0_g2        R2C99
# R_l0_g3        R3C99
# R_l0_g4        R4C99
# R_l0_g5        R5C99
# R_l0_g6        R6C99
# R_l0_g7        R7C99
# R_l0_g8        R8C99
# R_l0_g9        R9C99
# R_l0_g10      R10C99
# R_l0_g11      R11C99
# R_l0_g12      R12C99
# R_l0_g13      R13C99
# R_l0_g14      R14C99
# R_l0_g15      R15C99
# R_l0_g16      R16C99
# R_l0_g17      R17C99
# R_l0_g18      R18C99
# R_l0_g19      R19C99
# R_l0_g20      R20C99
# R_l0_g21      R21C99
# R_l0_g22      R22C99
# R_l0_g23      R23C99
# R_l0_g24      R24C99
# R_l0_g25      R25C99
# R_l0_g26      R26C99
# R_l0_g27      R27C99
# R_l0_g28      R28C99
# R_l0_g29      R29C99
# ........      ......
# R_l0_g9970  R9970C99
# R_l0_g9971  R9971C99
# R_l0_g9972  R9972C99
# R_l0_g9973  R9973C99
# R_l0_g9974  R9974C99
# R_l0_g9975  R9975C99
# R_l0_g9976  R9976C99
# R_l0_g9977  R9977C99
# R_l0_g9978  R9978C99
# R_l0_g9979  R9979C99
# R_l0_g9980  R9980C99
# R_l0_g9981  R9981C99
# R_l0_g9982  R9982C99
# R_l0_g9983  R9983C99
# R_l0_g9984  R9984C99
# R_l0_g9985  R9985C99
# R_l0_g9986  R9986C99
# R_l0_g9987  R9987C99
# R_l0_g9988  R9988C99
# R_l0_g9989  R9989C99
# R_l0_g9990  R9990C99
# R_l0_g9991  R9991C99
# R_l0_g9992  R9992C99
# R_l0_g9993  R9993C99
# R_l0_g9994  R9994C99
# R_l0_g9995  R9995C99
# R_l0_g9996  R9996C99
# R_l0_g9997  R9997C99
# R_l0_g9998  R9998C99
# R_l0_g9999  R9999C99
#
# [10000 rows x 100 columns]

# %%
pd.options.display.max_rows = 1000
pd.options.display.max_columns = 40

# %%
df
# Out:
# C0          C_l0_g0  C_l0_g1  C_l0_g2  C_l0_g3  C_l0_g4  C_l0_g5  C_l0_g6  \
# R0
# R_l0_g0        R0C0     R0C1     R0C2      NaN     R0C4      NaN     R0C6
# R_l0_g1        R1C0     R1C1     R1C2      NaN     R1C4     R1C5     R1C6
# R_l0_g2        R2C0     R2C1     R2C2     R2C3     R2C4     R2C5     R2C6
# R_l0_g3        R3C0     R3C1     R3C2     R3C3     R3C4     R3C5     R3C6
# R_l0_g4        R4C0     R4C1     R4C2     R4C3     R4C4     R4C5     R4C6
# R_l0_g5        R5C0     R5C1     R5C2      NaN     R5C4     R5C5     R5C6
# R_l0_g6        R6C0      NaN     R6C2     R6C3     R6C4     R6C5      NaN
# R_l0_g7         NaN     R7C1     R7C2     R7C3     R7C4     R7C5     R7C6
# R_l0_g8        R8C0     R8C1     R8C2     R8C3     R8C4      NaN     R8C6
# R_l0_g9        R9C0     R9C1     R9C2     R9C3     R9C4     R9C5     R9C6
# R_l0_g10      R10C0    R10C1    R10C2    R10C3    R10C4    R10C5    R10C6
# R_l0_g11      R11C0    R11C1    R11C2    R11C3    R11C4    R11C5    R11C6
# R_l0_g12      R12C0    R12C1    R12C2    R12C3    R12C4    R12C5    R12C6
# R_l0_g13      R13C0    R13C1    R13C2    R13C3    R13C4    R13C5    R13C6
# R_l0_g14      R14C0    R14C1    R14C2    R14C3      NaN    R14C5    R14C6
# R_l0_g15      R15C0    R15C1    R15C2    R15C3    R15C4    R15C5    R15C6
# R_l0_g16      R16C0    R16C1    R16C2    R16C3    R16C4    R16C5    R16C6
# R_l0_g17      R17C0      NaN    R17C2      NaN    R17C4    R17C5    R17C6
# R_l0_g18      R18C0    R18C1    R18C2    R18C3    R18C4    R18C5      NaN
# R_l0_g19      R19C0    R19C1    R19C2      NaN    R19C4    R19C5    R19C6
# R_l0_g20      R20C0    R20C1    R20C2    R20C3    R20C4    R20C5    R20C6
# R_l0_g21      R21C0    R21C1    R21C2    R21C3    R21C4    R21C5    R21C6
# R_l0_g22      R22C0    R22C1    R22C2    R22C3    R22C4    R22C5    R22C6
# R_l0_g23      R23C0    R23C1    R23C2    R23C3    R23C4    R23C5      NaN
# R_l0_g24      R24C0    R24C1    R24C2    R24C3    R24C4      NaN    R24C6
# R_l0_g25        NaN    R25C1    R25C2    R25C3    R25C4    R25C5    R25C6
# R_l0_g26      R26C0    R26C1    R26C2    R26C3    R26C4      NaN    R26C6
# R_l0_g27      R27C0    R27C1    R27C2    R27C3    R27C4      NaN    R27C6
# R_l0_g28      R28C0    R28C1    R28C2    R28C3    R28C4    R28C5    R28C6
# R_l0_g29      R29C0    R29C1    R29C2    R29C3    R29C4    R29C5    R29C6
# R_l0_g30      R30C0    R30C1    R30C2    R30C3    R30C4      NaN    R30C6
# R_l0_g31      R31C0    R31C1    R31C2      NaN    R31C4    R31C5    R31C6
# R_l0_g32      R32C0    R32C1    R32C2    R32C3    R32C4    R32C5    R32C6
# R_l0_g33      R33C0    R33C1    R33C2    R33C3    R33C4    R33C5    R33C6
# R_l0_g34      R34C0      NaN      NaN    R34C3    R34C4    R34C5    R34C6
# R_l0_g35      R35C0    R35C1      NaN    R35C3    R35C4      NaN      NaN
# R_l0_g36      R36C0    R36C1    R36C2    R36C3    R36C4    R36C5    R36C6
# R_l0_g37      R37C0    R37C1    R37C2    R37C3    R37C4    R37C5    R37C6
# R_l0_g38      R38C0    R38C1    R38C2    R38C3    R38C4    R38C5    R38C6
# R_l0_g39      R39C0    R39C1    R39C2    R39C3    R39C4    R39C5    R39C6
# R_l0_g40      R40C0    R40C1    R40C2    R40C3    R40C4    R40C5    R40C6
# R_l0_g41      R41C0    R41C1      NaN    R41C3    R41C4    R41C5    R41C6
# R_l0_g42      R42C0    R42C1    R42C2    R42C3      NaN    R42C5    R42C6
# R_l0_g43      R43C0    R43C1    R43C2    R43C3    R43C4    R43C5    R43C6
# R_l0_g44      R44C0    R44C1    R44C2    R44C3    R44C4    R44C5    R44C6
# R_l0_g45      R45C0    R45C1    R45C2    R45C3    R45C4    R45C5    R45C6
# R_l0_g46      R46C0    R46C1    R46C2    R46C3    R46C4    R46C5    R46C6
# R_l0_g47      R47C0    R47C1    R47C2    R47C3    R47C4    R47C5      NaN
# R_l0_g48      R48C0      NaN    R48C2    R48C3    R48C4      NaN    R48C6
# R_l0_g49      R49C0    R49C1    R49C2      NaN    R49C4    R49C5    R49C6
# R_l0_g50      R50C0    R50C1    R50C2    R50C3    R50C4    R50C5    R50C6
# R_l0_g51      R51C0    R51C1    R51C2      NaN    R51C4    R51C5    R51C6
# R_l0_g52      R52C0    R52C1    R52C2    R52C3    R52C4    R52C5      NaN
# R_l0_g53      R53C0    R53C1    R53C2    R53C3    R53C4    R53C5    R53C6
# R_l0_g54      R54C0    R54C1    R54C2    R54C3    R54C4      NaN    R54C6
# R_l0_g55      R55C0    R55C1    R55C2    R55C3    R55C4    R55C5    R55C6
# R_l0_g56      R56C0    R56C1    R56C2    R56C3    R56C4    R56C5    R56C6
# R_l0_g57      R57C0      NaN    R57C2    R57C3    R57C4    R57C5    R57C6
# R_l0_g58      R58C0    R58C1    R58C2    R58C3    R58C4    R58C5      NaN
# R_l0_g59      R59C0    R59C1    R59C2    R59C3    R59C4    R59C5    R59C6
# R_l0_g60      R60C0    R60C1    R60C2      NaN    R60C4    R60C5      NaN
# R_l0_g61      R61C0    R61C1    R61C2    R61C3      NaN    R61C5    R61C6
# R_l0_g62      R62C0      NaN    R62C2    R62C3      NaN    R62C5    R62C6
# R_l0_g63      R63C0      NaN    R63C2    R63C3    R63C4      NaN    R63C6
# R_l0_g64      R64C0    R64C1    R64C2      NaN    R64C4    R64C5      NaN
# R_l0_g65      R65C0    R65C1    R65C2    R65C3    R65C4      NaN    R65C6
# R_l0_g66      R66C0    R66C1    R66C2    R66C3    R66C4    R66C5      NaN
# R_l0_g67      R67C0    R67C1    R67C2    R67C3    R67C4    R67C5    R67C6
# R_l0_g68      R68C0    R68C1      NaN    R68C3    R68C4    R68C5    R68C6
# R_l0_g69      R69C0    R69C1    R69C2      NaN    R69C4    R69C5    R69C6
# R_l0_g70      R70C0      NaN    R70C2    R70C3    R70C4      NaN      NaN
# R_l0_g71      R71C0    R71C1    R71C2      NaN    R71C4    R71C5    R71C6
# R_l0_g72        NaN    R72C1    R72C2      NaN    R72C4      NaN    R72C6
# R_l0_g73      R73C0    R73C1    R73C2    R73C3    R73C4    R73C5    R73C6
# R_l0_g74      R74C0    R74C1    R74C2    R74C3    R74C4    R74C5    R74C6
# R_l0_g75      R75C0    R75C1    R75C2    R75C3    R75C4    R75C5    R75C6
# R_l0_g76        NaN    R76C1    R76C2      NaN    R76C4    R76C5    R76C6
# R_l0_g77      R77C0    R77C1    R77C2    R77C3    R77C4    R77C5    R77C6
# R_l0_g78      R78C0    R78C1    R78C2    R78C3    R78C4    R78C5    R78C6
# R_l0_g79        NaN    R79C1      NaN    R79C3    R79C4      NaN    R79C6
# R_l0_g80      R80C0    R80C1    R80C2      NaN    R80C4    R80C5    R80C6
# R_l0_g81      R81C0    R81C1    R81C2    R81C3    R81C4    R81C5    R81C6
# R_l0_g82      R82C0    R82C1    R82C2    R82C3    R82C4    R82C5    R82C6
# R_l0_g83      R83C0    R83C1      NaN    R83C3    R83C4    R83C5    R83C6
# R_l0_g84        NaN    R84C1    R84C2    R84C3    R84C4    R84C5    R84C6
# R_l0_g85      R85C0    R85C1    R85C2    R85C3    R85C4    R85C5    R85C6
# R_l0_g86      R86C0      NaN    R86C2    R86C3    R86C4    R86C5    R86C6
# R_l0_g87      R87C0    R87C1    R87C2    R87C3      NaN    R87C5    R87C6
# R_l0_g88        NaN    R88C1    R88C2    R88C3    R88C4    R88C5      NaN
# R_l0_g89      R89C0    R89C1    R89C2    R89C3    R89C4    R89C5    R89C6
# R_l0_g90        NaN    R90C1    R90C2    R90C3    R90C4    R90C5    R90C6
# R_l0_g91        NaN    R91C1    R91C2    R91C3    R91C4    R91C5    R91C6
# R_l0_g92      R92C0    R92C1    R92C2    R92C3    R92C4    R92C5      NaN
# R_l0_g93      R93C0    R93C1    R93C2      NaN    R93C4    R93C5    R93C6
# R_l0_g94      R94C0      NaN    R94C2    R94C3    R94C4    R94C5      NaN
# R_l0_g95      R95C0    R95C1    R95C2    R95C3    R95C4    R95C5    R95C6
# R_l0_g96      R96C0    R96C1      NaN    R96C3    R96C4    R96C5    R96C6
# R_l0_g97      R97C0    R97C1    R97C2    R97C3    R97C4    R97C5    R97C6
# R_l0_g98      R98C0    R98C1    R98C2    R98C3    R98C4    R98C5    R98C6
# R_l0_g99        NaN    R99C1    R99C2      NaN    R99C4    R99C5    R99C6
# R_l0_g100    R100C0   R100C1   R100C2   R100C3   R100C4   R100C5   R100C6
# R_l0_g101    R101C0   R101C1   R101C2   R101C3   R101C4   R101C5   R101C6
# R_l0_g102    R102C0   R102C1   R102C2   R102C3   R102C4   R102C5   R102C6
# R_l0_g103    R103C0   R103C1      NaN   R103C3   R103C4   R103C5   R103C6
# R_l0_g104       NaN   R104C1   R104C2   R104C3   R104C4   R104C5   R104C6
# R_l0_g105    R105C0   R105C1   R105C2   R105C3   R105C4   R105C5   R105C6
# R_l0_g106    R106C0   R106C1   R106C2   R106C3   R106C4   R106C5   R106C6
# R_l0_g107    R107C0   R107C1   R107C2   R107C3   R107C4   R107C5   R107C6
# R_l0_g108       NaN   R108C1   R108C2   R108C3   R108C4   R108C5   R108C6
# R_l0_g109    R109C0   R109C1   R109C2      NaN   R109C4   R109C5      NaN
# R_l0_g110    R110C0      NaN   R110C2   R110C3   R110C4   R110C5   R110C6
# R_l0_g111    R111C0   R111C1   R111C2   R111C3   R111C4   R111C5   R111C6
# R_l0_g112    R112C0   R112C1   R112C2   R112C3   R112C4      NaN   R112C6
# R_l0_g113    R113C0   R113C1   R113C2   R113C3   R113C4   R113C5   R113C6
# R_l0_g114    R114C0   R114C1   R114C2   R114C3   R114C4   R114C5   R114C6
# R_l0_g115    R115C0   R115C1   R115C2   R115C3   R115C4   R115C5   R115C6
# R_l0_g116       NaN   R116C1   R116C2   R116C3   R116C4   R116C5   R116C6
# R_l0_g117    R117C0      NaN   R117C2   R117C3   R117C4   R117C5   R117C6
# R_l0_g118    R118C0   R118C1   R118C2   R118C3   R118C4      NaN   R118C6
# R_l0_g119    R119C0   R119C1   R119C2   R119C3   R119C4   R119C5   R119C6
# R_l0_g120    R120C0   R120C1   R120C2   R120C3   R120C4      NaN   R120C6
# R_l0_g121    R121C0   R121C1      NaN   R121C3   R121C4   R121C5   R121C6
# R_l0_g122       NaN   R122C1   R122C2   R122C3   R122C4   R122C5   R122C6
# R_l0_g123    R123C0   R123C1   R123C2   R123C3   R123C4      NaN   R123C6
# R_l0_g124    R124C0   R124C1   R124C2   R124C3      NaN   R124C5   R124C6
# R_l0_g125       NaN   R125C1   R125C2   R125C3   R125C4   R125C5   R125C6
# R_l0_g126    R126C0      NaN   R126C2      NaN   R126C4   R126C5   R126C6
# R_l0_g127    R127C0   R127C1   R127C2   R127C3   R127C4   R127C5   R127C6
# R_l0_g128    R128C0   R128C1   R128C2   R128C3   R128C4   R128C5   R128C6
# R_l0_g129    R129C0   R129C1   R129C2   R129C3   R129C4   R129C5   R129C6
# R_l0_g130    R130C0   R130C1   R130C2   R130C3   R130C4   R130C5   R130C6
# R_l0_g131    R131C0   R131C1   R131C2   R131C3   R131C4   R131C5   R131C6
# R_l0_g132       NaN   R132C1   R132C2   R132C3   R132C4   R132C5   R132C6
# R_l0_g133    R133C0   R133C1   R133C2   R133C3   R133C4      NaN   R133C6
# R_l0_g134    R134C0   R134C1   R134C2   R134C3   R134C4   R134C5   R134C6
# R_l0_g135    R135C0   R135C1   R135C2   R135C3   R135C4   R135C5   R135C6
# R_l0_g136    R136C0   R136C1   R136C2      NaN   R136C4   R136C5   R136C6
# R_l0_g137    R137C0   R137C1   R137C2   R137C3   R137C4   R137C5   R137C6
# R_l0_g138    R138C0      NaN   R138C2      NaN   R138C4   R138C5   R138C6
# R_l0_g139    R139C0   R139C1   R139C2   R139C3   R139C4   R139C5   R139C6
# R_l0_g140    R140C0   R140C1   R140C2   R140C3   R140C4   R140C5   R140C6
# R_l0_g141    R141C0   R141C1   R141C2   R141C3   R141C4   R141C5   R141C6
# R_l0_g142    R142C0   R142C1   R142C2   R142C3   R142C4      NaN   R142C6
# R_l0_g143    R143C0   R143C1   R143C2   R143C3   R143C4   R143C5   R143C6
# R_l0_g144    R144C0   R144C1      NaN   R144C3   R144C4   R144C5      NaN
# R_l0_g145    R145C0   R145C1   R145C2   R145C3   R145C4   R145C5   R145C6
# R_l0_g146       NaN   R146C1   R146C2   R146C3   R146C4   R146C5   R146C6
# R_l0_g147    R147C0   R147C1   R147C2   R147C3   R147C4   R147C5   R147C6
# R_l0_g148    R148C0   R148C1   R148C2   R148C3   R148C4   R148C5   R148C6
# R_l0_g149    R149C0   R149C1   R149C2   R149C3   R149C4   R149C5   R149C6
# R_l0_g150    R150C0   R150C1   R150C2   R150C3   R150C4   R150C5   R150C6
# R_l0_g151    R151C0      NaN   R151C2   R151C3   R151C4   R151C5   R151C6
# R_l0_g152    R152C0   R152C1   R152C2   R152C3   R152C4   R152C5   R152C6
# R_l0_g153    R153C0      NaN      NaN   R153C3   R153C4   R153C5   R153C6
# R_l0_g154    R154C0   R154C1   R154C2   R154C3   R154C4   R154C5   R154C6
# R_l0_g155    R155C0   R155C1      NaN   R155C3   R155C4   R155C5   R155C6
# R_l0_g156    R156C0   R156C1   R156C2   R156C3   R156C4      NaN   R156C6
# R_l0_g157    R157C0   R157C1   R157C2   R157C3   R157C4   R157C5   R157C6
# R_l0_g158    R158C0   R158C1   R158C2   R158C3   R158C4   R158C5   R158C6
# R_l0_g159    R159C0   R159C1   R159C2   R159C3   R159C4   R159C5   R159C6
# R_l0_g160    R160C0   R160C1   R160C2   R160C3   R160C4   R160C5   R160C6
# R_l0_g161    R161C0      NaN   R161C2   R161C3   R161C4   R161C5   R161C6
# R_l0_g162       NaN   R162C1      NaN      NaN   R162C4   R162C5   R162C6
# R_l0_g163    R163C0   R163C1   R163C2   R163C3   R163C4   R163C5      NaN
# R_l0_g164    R164C0   R164C1   R164C2   R164C3   R164C4   R164C5   R164C6
# R_l0_g165    R165C0   R165C1   R165C2   R165C3      NaN   R165C5   R165C6
# R_l0_g166    R166C0   R166C1   R166C2   R166C3   R166C4   R166C5   R166C6
# R_l0_g167    R167C0      NaN   R167C2      NaN   R167C4      NaN   R167C6
# R_l0_g168    R168C0   R168C1   R168C2   R168C3   R168C4      NaN   R168C6
# R_l0_g169    R169C0   R169C1   R169C2   R169C3   R169C4   R169C5   R169C6
# R_l0_g170       NaN   R170C1   R170C2   R170C3   R170C4   R170C5   R170C6
# R_l0_g171    R171C0   R171C1   R171C2   R171C3      NaN      NaN      NaN
# R_l0_g172    R172C0   R172C1   R172C2   R172C3   R172C4      NaN   R172C6
# R_l0_g173    R173C0   R173C1   R173C2   R173C3   R173C4      NaN   R173C6
# R_l0_g174    R174C0   R174C1   R174C2   R174C3   R174C4      NaN   R174C6
# R_l0_g175    R175C0   R175C1   R175C2   R175C3   R175C4   R175C5   R175C6
# R_l0_g176    R176C0   R176C1   R176C2   R176C3   R176C4   R176C5   R176C6
# R_l0_g177    R177C0   R177C1   R177C2   R177C3   R177C4   R177C5   R177C6
# R_l0_g178    R178C0      NaN   R178C2   R178C3   R178C4   R178C5   R178C6
# R_l0_g179    R179C0   R179C1   R179C2      NaN   R179C4   R179C5   R179C6
# R_l0_g180    R180C0   R180C1   R180C2   R180C3   R180C4   R180C5   R180C6
# R_l0_g181    R181C0   R181C1   R181C2   R181C3   R181C4   R181C5   R181C6
# R_l0_g182    R182C0      NaN   R182C2   R182C3      NaN   R182C5   R182C6
# R_l0_g183    R183C0   R183C1   R183C2   R183C3      NaN   R183C5   R183C6
# R_l0_g184    R184C0   R184C1   R184C2   R184C3      NaN   R184C5   R184C6
# R_l0_g185       NaN   R185C1   R185C2   R185C3   R185C4   R185C5   R185C6
# R_l0_g186    R186C0   R186C1   R186C2   R186C3      NaN   R186C5   R186C6
# R_l0_g187    R187C0   R187C1   R187C2   R187C3   R187C4   R187C5   R187C6
# R_l0_g188    R188C0   R188C1   R188C2   R188C3   R188C4   R188C5   R188C6
# R_l0_g189    R189C0      NaN   R189C2   R189C3   R189C4      NaN      NaN
# R_l0_g190    R190C0      NaN   R190C2   R190C3   R190C4      NaN   R190C6
# R_l0_g191    R191C0   R191C1   R191C2   R191C3   R191C4   R191C5   R191C6
# R_l0_g192    R192C0   R192C1   R192C2   R192C3   R192C4   R192C5   R192C6
# R_l0_g193    R193C0   R193C1   R193C2   R193C3      NaN   R193C5   R193C6
# R_l0_g194    R194C0   R194C1      NaN   R194C3      NaN   R194C5   R194C6
# R_l0_g195    R195C0   R195C1   R195C2   R195C3   R195C4   R195C5      NaN
# R_l0_g196    R196C0   R196C1   R196C2   R196C3   R196C4   R196C5   R196C6
# R_l0_g197    R197C0   R197C1   R197C2   R197C3   R197C4   R197C5   R197C6
# R_l0_g198    R198C0   R198C1   R198C2   R198C3   R198C4   R198C5   R198C6
# R_l0_g199       NaN   R199C1   R199C2   R199C3   R199C4      NaN   R199C6
# R_l0_g200    R200C0      NaN      NaN   R200C3   R200C4   R200C5   R200C6
# R_l0_g201    R201C0   R201C1      NaN   R201C3   R201C4   R201C5   R201C6
# R_l0_g202    R202C0   R202C1   R202C2   R202C3   R202C4   R202C5   R202C6
# R_l0_g203       NaN   R203C1   R203C2   R203C3   R203C4   R203C5   R203C6
# R_l0_g204    R204C0   R204C1      NaN   R204C3   R204C4   R204C5   R204C6
# R_l0_g205    R205C0   R205C1   R205C2   R205C3      NaN   R205C5   R205C6
# R_l0_g206    R206C0   R206C1   R206C2   R206C3   R206C4   R206C5   R206C6
# R_l0_g207    R207C0   R207C1   R207C2   R207C3   R207C4   R207C5   R207C6
# R_l0_g208    R208C0   R208C1   R208C2   R208C3   R208C4      NaN      NaN
# R_l0_g209    R209C0   R209C1   R209C2   R209C3   R209C4      NaN      NaN
# R_l0_g210    R210C0   R210C1   R210C2   R210C3   R210C4   R210C5   R210C6
# R_l0_g211       NaN   R211C1   R211C2   R211C3   R211C4   R211C5      NaN
# R_l0_g212    R212C0   R212C1   R212C2   R212C3   R212C4   R212C5   R212C6
# R_l0_g213    R213C0   R213C1   R213C2   R213C3   R213C4   R213C5   R213C6
# R_l0_g214    R214C0   R214C1   R214C2   R214C3   R214C4   R214C5   R214C6
# R_l0_g215    R215C0   R215C1   R215C2   R215C3   R215C4   R215C5   R215C6
# R_l0_g216    R216C0   R216C1   R216C2   R216C3   R216C4   R216C5   R216C6
# R_l0_g217    R217C0   R217C1   R217C2   R217C3   R217C4   R217C5   R217C6
# R_l0_g218    R218C0   R218C1   R218C2   R218C3   R218C4   R218C5   R218C6
# R_l0_g219    R219C0   R219C1   R219C2   R219C3   R219C4      NaN   R219C6
# R_l0_g220    R220C0   R220C1   R220C2   R220C3   R220C4   R220C5   R220C6
# R_l0_g221    R221C0   R221C1   R221C2   R221C3   R221C4   R221C5   R221C6
# R_l0_g222       NaN      NaN   R222C2   R222C3      NaN      NaN   R222C6
# R_l0_g223       NaN   R223C1   R223C2   R223C3   R223C4   R223C5   R223C6
# R_l0_g224    R224C0   R224C1   R224C2   R224C3      NaN   R224C5   R224C6
# R_l0_g225    R225C0   R225C1      NaN   R225C3   R225C4   R225C5   R225C6
# R_l0_g226    R226C0   R226C1   R226C2   R226C3   R226C4   R226C5      NaN
# R_l0_g227    R227C0      NaN   R227C2   R227C3   R227C4      NaN      NaN
# R_l0_g228    R228C0   R228C1   R228C2   R228C3      NaN   R228C5   R228C6
# R_l0_g229    R229C0   R229C1   R229C2   R229C3   R229C4      NaN   R229C6
# R_l0_g230    R230C0   R230C1   R230C2   R230C3   R230C4   R230C5      NaN
# R_l0_g231    R231C0   R231C1   R231C2   R231C3      NaN   R231C5   R231C6
# R_l0_g232    R232C0   R232C1   R232C2   R232C3   R232C4   R232C5   R232C6
# R_l0_g233    R233C0   R233C1   R233C2   R233C3   R233C4   R233C5   R233C6
# R_l0_g234       NaN   R234C1   R234C2   R234C3   R234C4   R234C5   R234C6
# R_l0_g235    R235C0   R235C1   R235C2   R235C3      NaN   R235C5   R235C6
# R_l0_g236    R236C0   R236C1   R236C2   R236C3   R236C4   R236C5   R236C6
# R_l0_g237    R237C0   R237C1   R237C2   R237C3   R237C4   R237C5   R237C6
# R_l0_g238    R238C0   R238C1   R238C2   R238C3   R238C4   R238C5   R238C6
# R_l0_g239    R239C0   R239C1   R239C2   R239C3   R239C4   R239C5   R239C6
# R_l0_g240    R240C0   R240C1   R240C2   R240C3   R240C4   R240C5   R240C6
# R_l0_g241    R241C0   R241C1   R241C2   R241C3   R241C4   R241C5   R241C6
# R_l0_g242    R242C0   R242C1   R242C2   R242C3   R242C4   R242C5   R242C6
# R_l0_g243    R243C0   R243C1   R243C2   R243C3   R243C4      NaN   R243C6
# R_l0_g244    R244C0   R244C1   R244C2   R244C3   R244C4   R244C5   R244C6
# R_l0_g245    R245C0   R245C1   R245C2   R245C3   R245C4   R245C5   R245C6
# R_l0_g246    R246C0   R246C1   R246C2   R246C3      NaN   R246C5   R246C6
# R_l0_g247    R247C0   R247C1   R247C2   R247C3   R247C4   R247C5   R247C6
# R_l0_g248    R248C0   R248C1   R248C2   R248C3   R248C4   R248C5      NaN
# R_l0_g249    R249C0   R249C1      NaN   R249C3   R249C4   R249C5   R249C6
# R_l0_g250    R250C0   R250C1   R250C2   R250C3   R250C4   R250C5   R250C6
# R_l0_g251    R251C0   R251C1   R251C2   R251C3   R251C4   R251C5   R251C6
# R_l0_g252    R252C0   R252C1   R252C2   R252C3      NaN   R252C5   R252C6
# R_l0_g253    R253C0   R253C1   R253C2   R253C3   R253C4   R253C5   R253C6
# R_l0_g254    R254C0   R254C1   R254C2   R254C3   R254C4   R254C5   R254C6
# R_l0_g255    R255C0   R255C1   R255C2   R255C3   R255C4   R255C5   R255C6
# R_l0_g256    R256C0      NaN   R256C2   R256C3   R256C4   R256C5   R256C6
# R_l0_g257    R257C0      NaN   R257C2   R257C3   R257C4   R257C5   R257C6
# R_l0_g258    R258C0   R258C1   R258C2   R258C3   R258C4   R258C5      NaN
# R_l0_g259    R259C0      NaN   R259C2   R259C3   R259C4   R259C5   R259C6
# R_l0_g260    R260C0   R260C1   R260C2   R260C3   R260C4   R260C5   R260C6
# R_l0_g261    R261C0   R261C1   R261C2   R261C3   R261C4      NaN   R261C6
# R_l0_g262    R262C0      NaN   R262C2   R262C3   R262C4   R262C5   R262C6
# R_l0_g263    R263C0   R263C1   R263C2   R263C3   R263C4   R263C5   R263C6
# R_l0_g264    R264C0   R264C1   R264C2   R264C3   R264C4   R264C5   R264C6
# R_l0_g265       NaN   R265C1   R265C2   R265C3   R265C4   R265C5   R265C6
# R_l0_g266    R266C0   R266C1   R266C2   R266C3   R266C4   R266C5   R266C6
# R_l0_g267    R267C0   R267C1   R267C2   R267C3   R267C4   R267C5   R267C6
# R_l0_g268    R268C0   R268C1   R268C2   R268C3   R268C4   R268C5   R268C6
# R_l0_g269    R269C0   R269C1   R269C2   R269C3   R269C4   R269C5   R269C6
# R_l0_g270    R270C0   R270C1   R270C2   R270C3   R270C4   R270C5   R270C6
# R_l0_g271    R271C0   R271C1   R271C2   R271C3   R271C4   R271C5   R271C6
# R_l0_g272    R272C0   R272C1   R272C2      NaN   R272C4   R272C5   R272C6
# R_l0_g273    R273C0   R273C1   R273C2   R273C3   R273C4   R273C5   R273C6
# R_l0_g274    R274C0   R274C1   R274C2   R274C3   R274C4   R274C5   R274C6
# R_l0_g275    R275C0      NaN   R275C2   R275C3   R275C4   R275C5   R275C6
# R_l0_g276       NaN   R276C1   R276C2   R276C3   R276C4      NaN      NaN
# R_l0_g277    R277C0   R277C1   R277C2   R277C3   R277C4   R277C5   R277C6
# R_l0_g278    R278C0   R278C1   R278C2   R278C3   R278C4   R278C5   R278C6
# R_l0_g279    R279C0   R279C1   R279C2   R279C3   R279C4   R279C5   R279C6
# R_l0_g280    R280C0   R280C1   R280C2      NaN   R280C4   R280C5   R280C6
# R_l0_g281    R281C0   R281C1      NaN   R281C3   R281C4   R281C5   R281C6
# R_l0_g282    R282C0      NaN   R282C2   R282C3   R282C4      NaN   R282C6
# R_l0_g283    R283C0   R283C1   R283C2   R283C3      NaN   R283C5   R283C6
# R_l0_g284    R284C0   R284C1   R284C2   R284C3   R284C4   R284C5   R284C6
# R_l0_g285    R285C0   R285C1   R285C2   R285C3   R285C4   R285C5   R285C6
# R_l0_g286    R286C0   R286C1   R286C2   R286C3   R286C4      NaN   R286C6
# R_l0_g287    R287C0   R287C1   R287C2   R287C3   R287C4   R287C5   R287C6
# R_l0_g288    R288C0   R288C1   R288C2   R288C3   R288C4   R288C5      NaN
# R_l0_g289    R289C0   R289C1      NaN   R289C3   R289C4   R289C5   R289C6
# R_l0_g290    R290C0   R290C1   R290C2   R290C3   R290C4   R290C5   R290C6
# R_l0_g291       NaN   R291C1   R291C2   R291C3   R291C4   R291C5   R291C6
# R_l0_g292    R292C0   R292C1      NaN   R292C3      NaN   R292C5   R292C6
# R_l0_g293    R293C0   R293C1   R293C2   R293C3   R293C4   R293C5      NaN
# R_l0_g294    R294C0   R294C1   R294C2   R294C3      NaN   R294C5   R294C6
# R_l0_g295    R295C0   R295C1   R295C2   R295C3   R295C4   R295C5      NaN
# R_l0_g296    R296C0      NaN   R296C2      NaN      NaN   R296C5   R296C6
# R_l0_g297    R297C0   R297C1   R297C2   R297C3   R297C4   R297C5   R297C6
# R_l0_g298    R298C0   R298C1   R298C2   R298C3   R298C4   R298C5   R298C6
# R_l0_g299    R299C0   R299C1   R299C2   R299C3   R299C4   R299C5   R299C6
# R_l0_g300    R300C0   R300C1   R300C2      NaN   R300C4   R300C5   R300C6
# R_l0_g301    R301C0   R301C1      NaN      NaN   R301C4   R301C5   R301C6
# R_l0_g302    R302C0   R302C1   R302C2   R302C3   R302C4   R302C5   R302C6
# R_l0_g303    R303C0   R303C1   R303C2   R303C3   R303C4   R303C5   R303C6
# R_l0_g304    R304C0      NaN   R304C2   R304C3      NaN   R304C5   R304C6
# R_l0_g305    R305C0   R305C1   R305C2      NaN   R305C4   R305C5   R305C6
# R_l0_g306    R306C0   R306C1   R306C2   R306C3   R306C4   R306C5   R306C6
# R_l0_g307    R307C0   R307C1   R307C2   R307C3   R307C4   R307C5   R307C6
# R_l0_g308    R308C0   R308C1   R308C2   R308C3   R308C4   R308C5   R308C6
# R_l0_g309    R309C0   R309C1      NaN   R309C3   R309C4   R309C5   R309C6
# R_l0_g310    R310C0   R310C1   R310C2   R310C3   R310C4   R310C5   R310C6
# R_l0_g311    R311C0   R311C1   R311C2   R311C3   R311C4   R311C5   R311C6
# R_l0_g312    R312C0      NaN   R312C2   R312C3      NaN   R312C5   R312C6
# R_l0_g313    R313C0   R313C1   R313C2   R313C3   R313C4   R313C5   R313C6
# R_l0_g314       NaN   R314C1   R314C2   R314C3   R314C4   R314C5   R314C6
# R_l0_g315    R315C0   R315C1   R315C2   R315C3   R315C4      NaN   R315C6
# R_l0_g316    R316C0   R316C1   R316C2   R316C3   R316C4   R316C5   R316C6
# R_l0_g317    R317C0   R317C1   R317C2   R317C3   R317C4   R317C5   R317C6
# R_l0_g318    R318C0   R318C1   R318C2   R318C3   R318C4   R318C5   R318C6
# R_l0_g319    R319C0   R319C1   R319C2   R319C3   R319C4   R319C5   R319C6
# R_l0_g320    R320C0   R320C1   R320C2   R320C3   R320C4   R320C5   R320C6
# R_l0_g321    R321C0   R321C1   R321C2   R321C3   R321C4   R321C5   R321C6
# R_l0_g322    R322C0   R322C1      NaN   R322C3      NaN   R322C5   R322C6
# R_l0_g323    R323C0      NaN      NaN   R323C3   R323C4   R323C5      NaN
# R_l0_g324    R324C0   R324C1   R324C2   R324C3   R324C4   R324C5   R324C6
# R_l0_g325    R325C0   R325C1   R325C2   R325C3   R325C4   R325C5      NaN
# R_l0_g326    R326C0      NaN      NaN   R326C3   R326C4   R326C5   R326C6
# R_l0_g327    R327C0   R327C1   R327C2   R327C3   R327C4   R327C5   R327C6
# R_l0_g328    R328C0   R328C1   R328C2      NaN   R328C4   R328C5   R328C6
# R_l0_g329    R329C0   R329C1   R329C2   R329C3      NaN   R329C5   R329C6
# R_l0_g330    R330C0   R330C1   R330C2   R330C3   R330C4   R330C5      NaN
# R_l0_g331    R331C0   R331C1   R331C2   R331C3   R331C4   R331C5   R331C6
# R_l0_g332    R332C0   R332C1   R332C2   R332C3   R332C4   R332C5   R332C6
# R_l0_g333    R333C0   R333C1   R333C2   R333C3   R333C4   R333C5   R333C6
# R_l0_g334    R334C0   R334C1   R334C2   R334C3   R334C4   R334C5   R334C6
# R_l0_g335    R335C0   R335C1   R335C2   R335C3   R335C4   R335C5   R335C6
# R_l0_g336    R336C0   R336C1   R336C2   R336C3   R336C4   R336C5      NaN
# R_l0_g337    R337C0   R337C1   R337C2   R337C3   R337C4   R337C5   R337C6
# R_l0_g338    R338C0   R338C1   R338C2   R338C3   R338C4   R338C5   R338C6
# R_l0_g339    R339C0   R339C1   R339C2   R339C3      NaN      NaN   R339C6
# R_l0_g340    R340C0   R340C1   R340C2   R340C3   R340C4      NaN   R340C6
# R_l0_g341    R341C0      NaN   R341C2      NaN      NaN   R341C5   R341C6
# R_l0_g342    R342C0   R342C1   R342C2   R342C3   R342C4   R342C5   R342C6
# R_l0_g343    R343C0   R343C1   R343C2      NaN   R343C4   R343C5   R343C6
# R_l0_g344    R344C0   R344C1   R344C2   R344C3   R344C4      NaN   R344C6
# R_l0_g345    R345C0   R345C1   R345C2   R345C3      NaN   R345C5      NaN
# R_l0_g346    R346C0   R346C1   R346C2   R346C3   R346C4   R346C5   R346C6
# R_l0_g347    R347C0   R347C1      NaN   R347C3   R347C4   R347C5   R347C6
# R_l0_g348    R348C0   R348C1   R348C2   R348C3   R348C4   R348C5   R348C6
# R_l0_g349    R349C0   R349C1   R349C2   R349C3   R349C4   R349C5   R349C6
# R_l0_g350    R350C0   R350C1   R350C2   R350C3   R350C4   R350C5   R350C6
# R_l0_g351    R351C0   R351C1   R351C2   R351C3   R351C4   R351C5   R351C6
# R_l0_g352    R352C0   R352C1   R352C2   R352C3   R352C4   R352C5   R352C6
# R_l0_g353    R353C0   R353C1   R353C2   R353C3   R353C4   R353C5   R353C6
# R_l0_g354    R354C0   R354C1   R354C2   R354C3      NaN   R354C5   R354C6
# R_l0_g355       NaN   R355C1   R355C2   R355C3   R355C4   R355C5   R355C6
# R_l0_g356    R356C0   R356C1   R356C2   R356C3   R356C4   R356C5   R356C6
# R_l0_g357    R357C0   R357C1   R357C2   R357C3   R357C4   R357C5   R357C6
# R_l0_g358    R358C0   R358C1   R358C2   R358C3   R358C4   R358C5   R358C6
# R_l0_g359    R359C0      NaN   R359C2   R359C3   R359C4   R359C5   R359C6
# R_l0_g360    R360C0   R360C1   R360C2   R360C3   R360C4   R360C5      NaN
# R_l0_g361    R361C0   R361C1   R361C2   R361C3   R361C4   R361C5   R361C6
# R_l0_g362    R362C0   R362C1   R362C2   R362C3   R362C4   R362C5   R362C6
# R_l0_g363    R363C0   R363C1   R363C2   R363C3   R363C4   R363C5   R363C6
# R_l0_g364       NaN   R364C1   R364C2   R364C3   R364C4   R364C5   R364C6
# R_l0_g365    R365C0   R365C1   R365C2   R365C3   R365C4   R365C5   R365C6
# R_l0_g366    R366C0   R366C1   R366C2   R366C3   R366C4   R366C5   R366C6
# R_l0_g367    R367C0   R367C1   R367C2   R367C3   R367C4   R367C5   R367C6
# R_l0_g368    R368C0   R368C1   R368C2   R368C3   R368C4   R368C5   R368C6
# R_l0_g369    R369C0      NaN   R369C2   R369C3   R369C4   R369C5   R369C6
# R_l0_g370    R370C0   R370C1   R370C2   R370C3   R370C4   R370C5   R370C6
# R_l0_g371       NaN   R371C1      NaN   R371C3   R371C4   R371C5      NaN
# R_l0_g372    R372C0   R372C1   R372C2   R372C3   R372C4   R372C5   R372C6
# R_l0_g373    R373C0   R373C1   R373C2   R373C3   R373C4   R373C5   R373C6
# R_l0_g374    R374C0      NaN   R374C2   R374C3   R374C4   R374C5   R374C6
# R_l0_g375    R375C0      NaN   R375C2   R375C3   R375C4   R375C5   R375C6
# R_l0_g376    R376C0   R376C1   R376C2   R376C3      NaN   R376C5   R376C6
# R_l0_g377    R377C0      NaN      NaN   R377C3   R377C4   R377C5   R377C6
# R_l0_g378    R378C0   R378C1   R378C2   R378C3   R378C4   R378C5   R378C6
# R_l0_g379    R379C0      NaN      NaN   R379C3      NaN   R379C5   R379C6
# R_l0_g380    R380C0   R380C1   R380C2   R380C3   R380C4   R380C5   R380C6
# R_l0_g381    R381C0   R381C1   R381C2   R381C3   R381C4      NaN   R381C6
# R_l0_g382    R382C0   R382C1      NaN   R382C3   R382C4      NaN   R382C6
# R_l0_g383       NaN   R383C1   R383C2   R383C3   R383C4   R383C5   R383C6
# R_l0_g384    R384C0   R384C1   R384C2   R384C3   R384C4   R384C5   R384C6
# R_l0_g385    R385C0   R385C1   R385C2   R385C3   R385C4   R385C5   R385C6
# R_l0_g386    R386C0   R386C1   R386C2   R386C3   R386C4   R386C5   R386C6
# R_l0_g387       NaN   R387C1   R387C2   R387C3   R387C4   R387C5   R387C6
# R_l0_g388    R388C0   R388C1   R388C2   R388C3   R388C4   R388C5   R388C6
# R_l0_g389       NaN   R389C1   R389C2   R389C3   R389C4   R389C5      NaN
# R_l0_g390    R390C0   R390C1   R390C2      NaN   R390C4   R390C5   R390C6
# R_l0_g391       NaN      NaN   R391C2      NaN      NaN   R391C5   R391C6
# R_l0_g392    R392C0   R392C1   R392C2      NaN   R392C4   R392C5   R392C6
# R_l0_g393    R393C0   R393C1   R393C2   R393C3   R393C4   R393C5   R393C6
# R_l0_g394    R394C0   R394C1   R394C2   R394C3      NaN      NaN   R394C6
# R_l0_g395    R395C0   R395C1   R395C2   R395C3   R395C4   R395C5   R395C6
# R_l0_g396       NaN   R396C1   R396C2   R396C3   R396C4   R396C5      NaN
# R_l0_g397    R397C0   R397C1   R397C2   R397C3   R397C4   R397C5   R397C6
# R_l0_g398       NaN      NaN      NaN   R398C3   R398C4   R398C5   R398C6
# R_l0_g399    R399C0   R399C1   R399C2   R399C3   R399C4      NaN   R399C6
# R_l0_g400    R400C0   R400C1   R400C2   R400C3   R400C4   R400C5   R400C6
# R_l0_g401    R401C0   R401C1   R401C2   R401C3   R401C4   R401C5   R401C6
# R_l0_g402    R402C0   R402C1   R402C2   R402C3   R402C4   R402C5   R402C6
# R_l0_g403    R403C0   R403C1   R403C2   R403C3   R403C4   R403C5   R403C6
# R_l0_g404    R404C0   R404C1      NaN   R404C3   R404C4   R404C5   R404C6
# R_l0_g405    R405C0   R405C1   R405C2   R405C3   R405C4   R405C5   R405C6
# R_l0_g406    R406C0   R406C1   R406C2      NaN   R406C4   R406C5   R406C6
# R_l0_g407    R407C0   R407C1   R407C2   R407C3   R407C4   R407C5   R407C6
# R_l0_g408    R408C0   R408C1   R408C2   R408C3   R408C4   R408C5      NaN
# R_l0_g409    R409C0   R409C1   R409C2   R409C3   R409C4   R409C5   R409C6
# R_l0_g410    R410C0   R410C1      NaN   R410C3   R410C4   R410C5   R410C6
# R_l0_g411    R411C0   R411C1   R411C2   R411C3   R411C4   R411C5   R411C6
# R_l0_g412       NaN      NaN   R412C2      NaN   R412C4   R412C5   R412C6
# R_l0_g413       NaN      NaN   R413C2   R413C3   R413C4   R413C5   R413C6
# R_l0_g414    R414C0   R414C1   R414C2   R414C3   R414C4   R414C5   R414C6
# R_l0_g415    R415C0      NaN   R415C2   R415C3   R415C4   R415C5   R415C6
# R_l0_g416    R416C0   R416C1   R416C2   R416C3   R416C4   R416C5   R416C6
# R_l0_g417    R417C0   R417C1   R417C2   R417C3   R417C4   R417C5   R417C6
# R_l0_g418    R418C0      NaN      NaN   R418C3      NaN   R418C5      NaN
# R_l0_g419    R419C0   R419C1   R419C2   R419C3   R419C4   R419C5   R419C6
# R_l0_g420    R420C0      NaN   R420C2   R420C3   R420C4   R420C5   R420C6
# R_l0_g421    R421C0   R421C1   R421C2   R421C3   R421C4      NaN   R421C6
# R_l0_g422    R422C0   R422C1   R422C2   R422C3   R422C4   R422C5   R422C6
# R_l0_g423    R423C0   R423C1   R423C2   R423C3   R423C4   R423C5   R423C6
# R_l0_g424    R424C0   R424C1   R424C2   R424C3   R424C4   R424C5      NaN
# R_l0_g425       NaN   R425C1   R425C2   R425C3   R425C4   R425C5   R425C6
# R_l0_g426    R426C0   R426C1   R426C2      NaN   R426C4   R426C5   R426C6
# R_l0_g427    R427C0   R427C1   R427C2   R427C3   R427C4   R427C5   R427C6
# R_l0_g428    R428C0   R428C1   R428C2   R428C3   R428C4      NaN   R428C6
# R_l0_g429    R429C0   R429C1   R429C2   R429C3   R429C4   R429C5   R429C6
# R_l0_g430    R430C0   R430C1   R430C2   R430C3   R430C4   R430C5   R430C6
# R_l0_g431    R431C0   R431C1   R431C2   R431C3      NaN   R431C5   R431C6
# R_l0_g432    R432C0   R432C1   R432C2   R432C3      NaN   R432C5   R432C6
# R_l0_g433    R433C0   R433C1   R433C2   R433C3   R433C4   R433C5   R433C6
# R_l0_g434    R434C0      NaN   R434C2   R434C3   R434C4   R434C5   R434C6
# R_l0_g435    R435C0   R435C1   R435C2   R435C3   R435C4   R435C5   R435C6
# R_l0_g436    R436C0   R436C1   R436C2      NaN      NaN      NaN   R436C6
# R_l0_g437    R437C0   R437C1   R437C2   R437C3   R437C4   R437C5   R437C6
# R_l0_g438       NaN   R438C1   R438C2   R438C3   R438C4   R438C5   R438C6
# R_l0_g439    R439C0   R439C1      NaN   R439C3   R439C4   R439C5   R439C6
# R_l0_g440    R440C0   R440C1   R440C2   R440C3      NaN   R440C5   R440C6
# R_l0_g441    R441C0   R441C1   R441C2   R441C3   R441C4   R441C5   R441C6
# R_l0_g442    R442C0   R442C1   R442C2   R442C3   R442C4   R442C5      NaN
# R_l0_g443    R443C0      NaN   R443C2   R443C3   R443C4   R443C5   R443C6
# R_l0_g444       NaN   R444C1   R444C2      NaN   R444C4      NaN   R444C6
# R_l0_g445    R445C0   R445C1   R445C2   R445C3   R445C4   R445C5      NaN
# R_l0_g446    R446C0   R446C1   R446C2   R446C3   R446C4   R446C5   R446C6
# R_l0_g447       NaN   R447C1      NaN   R447C3   R447C4   R447C5   R447C6
# R_l0_g448       NaN   R448C1   R448C2   R448C3   R448C4   R448C5   R448C6
# R_l0_g449    R449C0   R449C1      NaN   R449C3   R449C4   R449C5   R449C6
# R_l0_g450    R450C0   R450C1   R450C2   R450C3   R450C4      NaN   R450C6
# R_l0_g451    R451C0   R451C1   R451C2      NaN   R451C4   R451C5   R451C6
# R_l0_g452    R452C0   R452C1   R452C2   R452C3   R452C4   R452C5   R452C6
# R_l0_g453    R453C0   R453C1   R453C2   R453C3   R453C4   R453C5   R453C6
# R_l0_g454    R454C0   R454C1   R454C2   R454C3   R454C4   R454C5   R454C6
# R_l0_g455    R455C0   R455C1   R455C2   R455C3   R455C4   R455C5   R455C6
# R_l0_g456    R456C0   R456C1      NaN   R456C3   R456C4   R456C5   R456C6
# R_l0_g457    R457C0   R457C1   R457C2   R457C3   R457C4   R457C5   R457C6
# R_l0_g458       NaN   R458C1   R458C2   R458C3      NaN   R458C5   R458C6
# R_l0_g459       NaN   R459C1   R459C2   R459C3   R459C4   R459C5   R459C6
# R_l0_g460    R460C0      NaN   R460C2   R460C3   R460C4   R460C5   R460C6
# R_l0_g461    R461C0   R461C1   R461C2   R461C3   R461C4   R461C5   R461C6
# R_l0_g462    R462C0   R462C1   R462C2      NaN   R462C4      NaN   R462C6
# R_l0_g463    R463C0   R463C1   R463C2   R463C3      NaN   R463C5   R463C6
# R_l0_g464    R464C0   R464C1   R464C2   R464C3   R464C4   R464C5   R464C6
# R_l0_g465    R465C0   R465C1   R465C2      NaN   R465C4   R465C5   R465C6
# R_l0_g466    R466C0   R466C1   R466C2      NaN   R466C4   R466C5   R466C6
# R_l0_g467    R467C0   R467C1   R467C2      NaN      NaN      NaN   R467C6
# R_l0_g468       NaN   R468C1   R468C2   R468C3      NaN   R468C5   R468C6
# R_l0_g469    R469C0   R469C1   R469C2   R469C3   R469C4   R469C5   R469C6
# R_l0_g470       NaN   R470C1   R470C2   R470C3   R470C4   R470C5      NaN
# R_l0_g471    R471C0   R471C1   R471C2      NaN      NaN   R471C5   R471C6
# R_l0_g472    R472C0   R472C1   R472C2      NaN   R472C4   R472C5      NaN
# R_l0_g473       NaN   R473C1   R473C2   R473C3   R473C4   R473C5   R473C6
# R_l0_g474    R474C0   R474C1   R474C2   R474C3   R474C4   R474C5   R474C6
# R_l0_g475    R475C0   R475C1   R475C2   R475C3   R475C4   R475C5   R475C6
# R_l0_g476    R476C0   R476C1   R476C2   R476C3   R476C4   R476C5      NaN
# R_l0_g477    R477C0   R477C1   R477C2   R477C3   R477C4   R477C5   R477C6
# R_l0_g478    R478C0   R478C1   R478C2   R478C3   R478C4   R478C5   R478C6
# R_l0_g479    R479C0   R479C1   R479C2   R479C3   R479C4   R479C5   R479C6
# R_l0_g480       NaN   R480C1   R480C2   R480C3   R480C4   R480C5   R480C6
# R_l0_g481    R481C0   R481C1      NaN   R481C3   R481C4   R481C5   R481C6
# R_l0_g482    R482C0   R482C1   R482C2   R482C3   R482C4   R482C5   R482C6
# R_l0_g483    R483C0   R483C1   R483C2   R483C3   R483C4   R483C5   R483C6
# R_l0_g484    R484C0   R484C1   R484C2   R484C3   R484C4   R484C5   R484C6
# R_l0_g485    R485C0   R485C1   R485C2   R485C3   R485C4   R485C5   R485C6
# R_l0_g486    R486C0   R486C1      NaN   R486C3   R486C4   R486C5      NaN
# R_l0_g487    R487C0   R487C1      NaN   R487C3   R487C4   R487C5   R487C6
# R_l0_g488       NaN   R488C1   R488C2   R488C3   R488C4   R488C5   R488C6
# R_l0_g489    R489C0   R489C1   R489C2   R489C3   R489C4   R489C5   R489C6
# R_l0_g490    R490C0   R490C1   R490C2   R490C3   R490C4   R490C5   R490C6
# R_l0_g491    R491C0   R491C1   R491C2   R491C3   R491C4   R491C5   R491C6
# R_l0_g492    R492C0   R492C1      NaN   R492C3   R492C4   R492C5   R492C6
# R_l0_g493    R493C0      NaN   R493C2   R493C3   R493C4   R493C5   R493C6
# R_l0_g494    R494C0   R494C1   R494C2      NaN   R494C4   R494C5   R494C6
# R_l0_g495    R495C0   R495C1   R495C2   R495C3   R495C4   R495C5      NaN
# R_l0_g496    R496C0   R496C1   R496C2   R496C3   R496C4   R496C5   R496C6
# R_l0_g497    R497C0   R497C1   R497C2   R497C3   R497C4   R497C5   R497C6
# R_l0_g498    R498C0   R498C1   R498C2   R498C3   R498C4   R498C5      NaN
# R_l0_g499    R499C0   R499C1   R499C2   R499C3   R499C4   R499C5   R499C6
# .........    ......   ......   ......   ......   ......   ......      ...
# R_l0_g9500  R9500C0  R9500C1  R9500C2  R9500C3  R9500C4      NaN  R9500C6
# R_l0_g9501  R9501C0  R9501C1      NaN  R9501C3      NaN  R9501C5  R9501C6
# R_l0_g9502  R9502C0  R9502C1  R9502C2  R9502C3      NaN  R9502C5  R9502C6
# R_l0_g9503  R9503C0  R9503C1  R9503C2  R9503C3  R9503C4  R9503C5  R9503C6
# R_l0_g9504  R9504C0  R9504C1  R9504C2  R9504C3      NaN  R9504C5  R9504C6
# R_l0_g9505  R9505C0  R9505C1  R9505C2  R9505C3  R9505C4  R9505C5  R9505C6
# R_l0_g9506  R9506C0  R9506C1  R9506C2  R9506C3  R9506C4  R9506C5      NaN
# R_l0_g9507  R9507C0  R9507C1  R9507C2  R9507C3      NaN  R9507C5  R9507C6
# R_l0_g9508  R9508C0  R9508C1  R9508C2  R9508C3  R9508C4  R9508C5  R9508C6
# R_l0_g9509  R9509C0  R9509C1  R9509C2  R9509C3  R9509C4  R9509C5  R9509C6
# R_l0_g9510  R9510C0  R9510C1  R9510C2  R9510C3  R9510C4  R9510C5  R9510C6
# R_l0_g9511  R9511C0  R9511C1      NaN  R9511C3  R9511C4  R9511C5  R9511C6
# R_l0_g9512  R9512C0  R9512C1  R9512C2  R9512C3  R9512C4  R9512C5  R9512C6
# R_l0_g9513      NaN  R9513C1      NaN  R9513C3  R9513C4  R9513C5  R9513C6
# R_l0_g9514  R9514C0  R9514C1  R9514C2  R9514C3      NaN  R9514C5  R9514C6
# R_l0_g9515  R9515C0  R9515C1  R9515C2  R9515C3  R9515C4  R9515C5      NaN
# R_l0_g9516  R9516C0  R9516C1  R9516C2  R9516C3  R9516C4  R9516C5  R9516C6
# R_l0_g9517  R9517C0  R9517C1  R9517C2  R9517C3  R9517C4  R9517C5  R9517C6
# R_l0_g9518  R9518C0      NaN  R9518C2  R9518C3  R9518C4  R9518C5  R9518C6
# R_l0_g9519  R9519C0  R9519C1  R9519C2  R9519C3  R9519C4  R9519C5  R9519C6
# R_l0_g9520  R9520C0  R9520C1  R9520C2  R9520C3  R9520C4  R9520C5  R9520C6
# R_l0_g9521  R9521C0  R9521C1  R9521C2  R9521C3  R9521C4  R9521C5  R9521C6
# R_l0_g9522      NaN  R9522C1      NaN  R9522C3  R9522C4  R9522C5  R9522C6
# R_l0_g9523  R9523C0  R9523C1      NaN  R9523C3      NaN  R9523C5  R9523C6
# R_l0_g9524  R9524C0  R9524C1  R9524C2  R9524C3  R9524C4  R9524C5      NaN
# R_l0_g9525  R9525C0  R9525C1  R9525C2      NaN  R9525C4  R9525C5  R9525C6
# R_l0_g9526  R9526C0  R9526C1  R9526C2  R9526C3  R9526C4  R9526C5      NaN
# R_l0_g9527      NaN      NaN      NaN      NaN  R9527C4  R9527C5  R9527C6
# R_l0_g9528  R9528C0  R9528C1  R9528C2  R9528C3  R9528C4  R9528C5      NaN
# R_l0_g9529  R9529C0      NaN  R9529C2  R9529C3  R9529C4      NaN      NaN
# R_l0_g9530  R9530C0  R9530C1  R9530C2  R9530C3  R9530C4      NaN  R9530C6
# R_l0_g9531  R9531C0  R9531C1  R9531C2      NaN      NaN  R9531C5  R9531C6
# R_l0_g9532  R9532C0  R9532C1      NaN  R9532C3  R9532C4  R9532C5      NaN
# R_l0_g9533      NaN  R9533C1  R9533C2  R9533C3  R9533C4  R9533C5  R9533C6
# R_l0_g9534  R9534C0  R9534C1      NaN  R9534C3  R9534C4  R9534C5  R9534C6
# R_l0_g9535  R9535C0      NaN  R9535C2  R9535C3      NaN  R9535C5  R9535C6
# R_l0_g9536  R9536C0      NaN      NaN  R9536C3  R9536C4  R9536C5  R9536C6
# R_l0_g9537  R9537C0  R9537C1  R9537C2  R9537C3  R9537C4  R9537C5  R9537C6
# R_l0_g9538      NaN  R9538C1  R9538C2  R9538C3  R9538C4  R9538C5  R9538C6
# R_l0_g9539      NaN  R9539C1  R9539C2  R9539C3  R9539C4  R9539C5  R9539C6
# R_l0_g9540  R9540C0  R9540C1  R9540C2  R9540C3  R9540C4  R9540C5  R9540C6
# R_l0_g9541  R9541C0  R9541C1  R9541C2  R9541C3  R9541C4  R9541C5  R9541C6
# R_l0_g9542      NaN  R9542C1  R9542C2  R9542C3  R9542C4  R9542C5  R9542C6
# R_l0_g9543  R9543C0  R9543C1  R9543C2  R9543C3      NaN  R9543C5  R9543C6
# R_l0_g9544  R9544C0  R9544C1  R9544C2      NaN  R9544C4  R9544C5  R9544C6
# R_l0_g9545  R9545C0  R9545C1  R9545C2      NaN  R9545C4      NaN  R9545C6
# R_l0_g9546  R9546C0  R9546C1  R9546C2  R9546C3  R9546C4  R9546C5  R9546C6
# R_l0_g9547  R9547C0      NaN  R9547C2  R9547C3  R9547C4  R9547C5  R9547C6
# R_l0_g9548  R9548C0  R9548C1  R9548C2  R9548C3  R9548C4  R9548C5  R9548C6
# R_l0_g9549  R9549C0      NaN  R9549C2      NaN  R9549C4      NaN  R9549C6
# R_l0_g9550  R9550C0  R9550C1  R9550C2  R9550C3  R9550C4  R9550C5  R9550C6
# R_l0_g9551  R9551C0  R9551C1  R9551C2  R9551C3  R9551C4  R9551C5  R9551C6
# R_l0_g9552  R9552C0  R9552C1  R9552C2  R9552C3  R9552C4  R9552C5  R9552C6
# R_l0_g9553  R9553C0  R9553C1  R9553C2  R9553C3  R9553C4  R9553C5  R9553C6
# R_l0_g9554  R9554C0  R9554C1      NaN  R9554C3  R9554C4  R9554C5  R9554C6
# R_l0_g9555  R9555C0  R9555C1  R9555C2      NaN  R9555C4  R9555C5  R9555C6
# R_l0_g9556  R9556C0  R9556C1  R9556C2  R9556C3      NaN  R9556C5  R9556C6
# R_l0_g9557  R9557C0  R9557C1      NaN  R9557C3  R9557C4  R9557C5      NaN
# R_l0_g9558  R9558C0  R9558C1      NaN  R9558C3  R9558C4      NaN  R9558C6
# R_l0_g9559  R9559C0  R9559C1  R9559C2  R9559C3  R9559C4      NaN  R9559C6
# R_l0_g9560  R9560C0  R9560C1  R9560C2  R9560C3  R9560C4  R9560C5  R9560C6
# R_l0_g9561      NaN  R9561C1  R9561C2  R9561C3  R9561C4  R9561C5  R9561C6
# R_l0_g9562  R9562C0  R9562C1  R9562C2  R9562C3  R9562C4  R9562C5  R9562C6
# R_l0_g9563      NaN  R9563C1  R9563C2  R9563C3  R9563C4  R9563C5  R9563C6
# R_l0_g9564  R9564C0  R9564C1  R9564C2  R9564C3  R9564C4  R9564C5  R9564C6
# R_l0_g9565  R9565C0      NaN  R9565C2  R9565C3  R9565C4  R9565C5      NaN
# R_l0_g9566  R9566C0  R9566C1  R9566C2      NaN  R9566C4  R9566C5  R9566C6
# R_l0_g9567  R9567C0  R9567C1  R9567C2  R9567C3  R9567C4  R9567C5  R9567C6
# R_l0_g9568  R9568C0  R9568C1  R9568C2  R9568C3  R9568C4      NaN  R9568C6
# R_l0_g9569  R9569C0  R9569C1  R9569C2  R9569C3  R9569C4  R9569C5  R9569C6
# R_l0_g9570  R9570C0  R9570C1  R9570C2  R9570C3  R9570C4  R9570C5  R9570C6
# R_l0_g9571  R9571C0  R9571C1  R9571C2  R9571C3  R9571C4  R9571C5  R9571C6
# R_l0_g9572  R9572C0  R9572C1  R9572C2  R9572C3      NaN  R9572C5  R9572C6
# R_l0_g9573  R9573C0  R9573C1  R9573C2  R9573C3  R9573C4  R9573C5  R9573C6
# R_l0_g9574  R9574C0  R9574C1  R9574C2  R9574C3  R9574C4  R9574C5  R9574C6
# R_l0_g9575      NaN  R9575C1  R9575C2  R9575C3  R9575C4  R9575C5  R9575C6
# R_l0_g9576      NaN  R9576C1  R9576C2  R9576C3  R9576C4  R9576C5  R9576C6
# R_l0_g9577  R9577C0  R9577C1  R9577C2  R9577C3  R9577C4  R9577C5  R9577C6
# R_l0_g9578  R9578C0  R9578C1  R9578C2  R9578C3  R9578C4  R9578C5  R9578C6
# R_l0_g9579  R9579C0  R9579C1  R9579C2  R9579C3      NaN  R9579C5  R9579C6
# R_l0_g9580  R9580C0  R9580C1  R9580C2      NaN      NaN  R9580C5  R9580C6
# R_l0_g9581  R9581C0  R9581C1  R9581C2  R9581C3  R9581C4  R9581C5  R9581C6
# R_l0_g9582  R9582C0      NaN  R9582C2  R9582C3      NaN      NaN  R9582C6
# R_l0_g9583      NaN  R9583C1  R9583C2  R9583C3  R9583C4  R9583C5  R9583C6
# R_l0_g9584  R9584C0  R9584C1  R9584C2  R9584C3  R9584C4  R9584C5  R9584C6
# R_l0_g9585  R9585C0  R9585C1  R9585C2  R9585C3  R9585C4  R9585C5  R9585C6
# R_l0_g9586  R9586C0  R9586C1  R9586C2  R9586C3  R9586C4  R9586C5  R9586C6
# R_l0_g9587      NaN  R9587C1  R9587C2  R9587C3  R9587C4  R9587C5  R9587C6
# R_l0_g9588  R9588C0  R9588C1  R9588C2  R9588C3  R9588C4      NaN      NaN
# R_l0_g9589  R9589C0  R9589C1      NaN  R9589C3  R9589C4  R9589C5  R9589C6
# R_l0_g9590  R9590C0  R9590C1  R9590C2  R9590C3  R9590C4  R9590C5  R9590C6
# R_l0_g9591  R9591C0  R9591C1  R9591C2  R9591C3  R9591C4  R9591C5  R9591C6
# R_l0_g9592  R9592C0  R9592C1  R9592C2  R9592C3  R9592C4  R9592C5      NaN
# R_l0_g9593  R9593C0  R9593C1  R9593C2  R9593C3  R9593C4  R9593C5  R9593C6
# R_l0_g9594  R9594C0  R9594C1  R9594C2  R9594C3  R9594C4  R9594C5  R9594C6
# R_l0_g9595  R9595C0  R9595C1  R9595C2      NaN  R9595C4  R9595C5  R9595C6
# R_l0_g9596  R9596C0  R9596C1  R9596C2  R9596C3  R9596C4  R9596C5  R9596C6
# R_l0_g9597  R9597C0  R9597C1  R9597C2  R9597C3  R9597C4  R9597C5  R9597C6
# R_l0_g9598  R9598C0  R9598C1  R9598C2  R9598C3  R9598C4  R9598C5  R9598C6
# R_l0_g9599  R9599C0  R9599C1  R9599C2  R9599C3  R9599C4  R9599C5  R9599C6
# R_l0_g9600  R9600C0      NaN  R9600C2  R9600C3  R9600C4  R9600C5  R9600C6
# R_l0_g9601  R9601C0  R9601C1  R9601C2  R9601C3  R9601C4  R9601C5  R9601C6
# R_l0_g9602  R9602C0  R9602C1      NaN      NaN      NaN  R9602C5  R9602C6
# R_l0_g9603  R9603C0  R9603C1  R9603C2  R9603C3  R9603C4  R9603C5  R9603C6
# R_l0_g9604  R9604C0  R9604C1  R9604C2  R9604C3  R9604C4  R9604C5      NaN
# R_l0_g9605  R9605C0  R9605C1  R9605C2  R9605C3      NaN  R9605C5  R9605C6
# R_l0_g9606  R9606C0  R9606C1  R9606C2  R9606C3  R9606C4  R9606C5  R9606C6
# R_l0_g9607      NaN      NaN  R9607C2  R9607C3  R9607C4  R9607C5  R9607C6
# R_l0_g9608  R9608C0  R9608C1  R9608C2  R9608C3  R9608C4  R9608C5  R9608C6
# R_l0_g9609  R9609C0  R9609C1  R9609C2  R9609C3  R9609C4      NaN  R9609C6
# R_l0_g9610      NaN  R9610C1      NaN  R9610C3  R9610C4  R9610C5  R9610C6
# R_l0_g9611      NaN  R9611C1  R9611C2  R9611C3      NaN  R9611C5      NaN
# R_l0_g9612  R9612C0  R9612C1  R9612C2  R9612C3  R9612C4  R9612C5  R9612C6
# R_l0_g9613  R9613C0  R9613C1  R9613C2  R9613C3  R9613C4  R9613C5  R9613C6
# R_l0_g9614  R9614C0  R9614C1  R9614C2  R9614C3  R9614C4  R9614C5  R9614C6
# R_l0_g9615  R9615C0  R9615C1  R9615C2  R9615C3      NaN  R9615C5  R9615C6
# R_l0_g9616  R9616C0  R9616C1  R9616C2  R9616C3  R9616C4      NaN  R9616C6
# R_l0_g9617  R9617C0  R9617C1  R9617C2  R9617C3  R9617C4  R9617C5  R9617C6
# R_l0_g9618      NaN  R9618C1  R9618C2  R9618C3  R9618C4  R9618C5  R9618C6
# R_l0_g9619      NaN  R9619C1  R9619C2  R9619C3  R9619C4  R9619C5  R9619C6
# ...
# R_l0_g9629  R9629C97  R9629C98  R9629C99
# R_l0_g9630  R9630C97  R9630C98  R9630C99
# R_l0_g9631  R9631C97  R9631C98  R9631C99
# R_l0_g9632  R9632C97  R9632C98  R9632C99
# R_l0_g9633  R9633C97  R9633C98  R9633C99
# R_l0_g9634  R9634C97  R9634C98  R9634C99
# R_l0_g9635  R9635C97  R9635C98  R9635C99
# R_l0_g9636  R9636C97  R9636C98  R9636C99
# R_l0_g9637  R9637C97  R9637C98  R9637C99
# R_l0_g9638  R9638C97  R9638C98  R9638C99
# R_l0_g9639  R9639C97  R9639C98  R9639C99
# R_l0_g9640  R9640C97  R9640C98  R9640C99
# R_l0_g9641  R9641C97  R9641C98  R9641C99
# R_l0_g9642  R9642C97  R9642C98  R9642C99
# R_l0_g9643  R9643C97  R9643C98  R9643C99
# R_l0_g9644  R9644C97  R9644C98  R9644C99
# R_l0_g9645  R9645C97  R9645C98  R9645C99
# R_l0_g9646  R9646C97  R9646C98  R9646C99
# R_l0_g9647  R9647C97  R9647C98  R9647C99
# R_l0_g9648  R9648C97  R9648C98  R9648C99
# R_l0_g9649  R9649C97  R9649C98  R9649C99
# R_l0_g9650  R9650C97  R9650C98  R9650C99
# R_l0_g9651  R9651C97  R9651C98  R9651C99
# R_l0_g9652  R9652C97  R9652C98  R9652C99
# R_l0_g9653  R9653C97  R9653C98  R9653C99
# R_l0_g9654  R9654C97  R9654C98  R9654C99
# R_l0_g9655  R9655C97  R9655C98  R9655C99
# R_l0_g9656  R9656C97  R9656C98  R9656C99
# R_l0_g9657  R9657C97  R9657C98  R9657C99
# R_l0_g9658  R9658C97  R9658C98  R9658C99
# R_l0_g9659  R9659C97  R9659C98  R9659C99
# R_l0_g9660  R9660C97  R9660C98  R9660C99
# R_l0_g9661  R9661C97  R9661C98  R9661C99
# R_l0_g9662  R9662C97  R9662C98  R9662C99
# R_l0_g9663  R9663C97  R9663C98  R9663C99
# R_l0_g9664  R9664C97  R9664C98  R9664C99
# R_l0_g9665  R9665C97  R9665C98  R9665C99
# R_l0_g9666  R9666C97  R9666C98  R9666C99
# R_l0_g9667  R9667C97  R9667C98  R9667C99
# R_l0_g9668  R9668C97  R9668C98  R9668C99
# R_l0_g9669  R9669C97  R9669C98  R9669C99
# R_l0_g9670  R9670C97  R9670C98  R9670C99
# R_l0_g9671  R9671C97  R9671C98  R9671C99
# R_l0_g9672  R9672C97  R9672C98  R9672C99
# R_l0_g9673  R9673C97  R9673C98  R9673C99
# R_l0_g9674  R9674C97  R9674C98  R9674C99
# R_l0_g9675  R9675C97  R9675C98  R9675C99
# R_l0_g9676  R9676C97  R9676C98  R9676C99
# R_l0_g9677  R9677C97  R9677C98  R9677C99
# R_l0_g9678  R9678C97  R9678C98  R9678C99
# R_l0_g9679  R9679C97  R9679C98  R9679C99
# R_l0_g9680  R9680C97  R9680C98  R9680C99
# R_l0_g9681  R9681C97  R9681C98  R9681C99
# R_l0_g9682  R9682C97  R9682C98  R9682C99
# R_l0_g9683  R9683C97  R9683C98  R9683C99
# R_l0_g9684  R9684C97  R9684C98  R9684C99
# R_l0_g9685  R9685C97  R9685C98  R9685C99
# R_l0_g9686  R9686C97  R9686C98  R9686C99
# R_l0_g9687  R9687C97  R9687C98  R9687C99
# R_l0_g9688  R9688C97  R9688C98  R9688C99
# R_l0_g9689  R9689C97  R9689C98  R9689C99
# R_l0_g9690  R9690C97  R9690C98  R9690C99
# R_l0_g9691  R9691C97  R9691C98  R9691C99
# R_l0_g9692  R9692C97  R9692C98  R9692C99
# R_l0_g9693  R9693C97  R9693C98  R9693C99
# R_l0_g9694  R9694C97  R9694C98  R9694C99
# R_l0_g9695  R9695C97  R9695C98  R9695C99
# R_l0_g9696  R9696C97  R9696C98  R9696C99
# R_l0_g9697  R9697C97  R9697C98  R9697C99
# R_l0_g9698  R9698C97  R9698C98  R9698C99
# R_l0_g9699  R9699C97  R9699C98  R9699C99
# R_l0_g9700  R9700C97  R9700C98  R9700C99
# R_l0_g9701  R9701C97  R9701C98  R9701C99
# R_l0_g9702  R9702C97  R9702C98  R9702C99
# R_l0_g9703  R9703C97  R9703C98  R9703C99
# R_l0_g9704  R9704C97  R9704C98  R9704C99
# R_l0_g9705  R9705C97  R9705C98  R9705C99
# R_l0_g9706  R9706C97  R9706C98  R9706C99
# R_l0_g9707  R9707C97  R9707C98  R9707C99
# R_l0_g9708  R9708C97  R9708C98  R9708C99
# R_l0_g9709  R9709C97  R9709C98  R9709C99
# R_l0_g9710  R9710C97  R9710C98  R9710C99
# R_l0_g9711  R9711C97  R9711C98  R9711C99
# R_l0_g9712  R9712C97  R9712C98  R9712C99
# R_l0_g9713  R9713C97  R9713C98  R9713C99
# R_l0_g9714  R9714C97  R9714C98  R9714C99
# R_l0_g9715  R9715C97  R9715C98  R9715C99
# R_l0_g9716  R9716C97  R9716C98  R9716C99
# R_l0_g9717  R9717C97  R9717C98  R9717C99
# R_l0_g9718  R9718C97  R9718C98  R9718C99
# R_l0_g9719  R9719C97  R9719C98  R9719C99
# R_l0_g9720  R9720C97  R9720C98  R9720C99
# R_l0_g9721  R9721C97  R9721C98  R9721C99
# R_l0_g9722  R9722C97  R9722C98  R9722C99
# R_l0_g9723  R9723C97  R9723C98  R9723C99
# R_l0_g9724  R9724C97  R9724C98  R9724C99
# R_l0_g9725  R9725C97  R9725C98  R9725C99
# R_l0_g9726  R9726C97  R9726C98  R9726C99
# R_l0_g9727  R9727C97  R9727C98  R9727C99
# R_l0_g9728  R9728C97  R9728C98  R9728C99
# R_l0_g9729  R9729C97  R9729C98  R9729C99
# R_l0_g9730  R9730C97  R9730C98  R9730C99
# R_l0_g9731  R9731C97  R9731C98  R9731C99
# R_l0_g9732  R9732C97  R9732C98  R9732C99
# R_l0_g9733  R9733C97  R9733C98  R9733C99
# R_l0_g9734  R9734C97  R9734C98  R9734C99
# R_l0_g9735  R9735C97  R9735C98  R9735C99
# R_l0_g9736  R9736C97  R9736C98  R9736C99
# R_l0_g9737  R9737C97  R9737C98  R9737C99
# R_l0_g9738  R9738C97  R9738C98  R9738C99
# R_l0_g9739  R9739C97  R9739C98  R9739C99
# R_l0_g9740  R9740C97  R9740C98  R9740C99
# R_l0_g9741  R9741C97  R9741C98  R9741C99
# R_l0_g9742  R9742C97  R9742C98  R9742C99
# R_l0_g9743  R9743C97  R9743C98  R9743C99
# R_l0_g9744  R9744C97  R9744C98  R9744C99
# R_l0_g9745  R9745C97  R9745C98  R9745C99
# R_l0_g9746  R9746C97  R9746C98  R9746C99
# R_l0_g9747  R9747C97  R9747C98  R9747C99
# R_l0_g9748  R9748C97  R9748C98  R9748C99
# R_l0_g9749  R9749C97  R9749C98  R9749C99
# R_l0_g9750  R9750C97  R9750C98  R9750C99
# R_l0_g9751  R9751C97  R9751C98  R9751C99
# R_l0_g9752  R9752C97  R9752C98  R9752C99
# R_l0_g9753  R9753C97  R9753C98  R9753C99
# R_l0_g9754  R9754C97  R9754C98  R9754C99
# R_l0_g9755  R9755C97  R9755C98  R9755C99
# R_l0_g9756  R9756C97  R9756C98  R9756C99
# R_l0_g9757  R9757C97  R9757C98  R9757C99
# R_l0_g9758  R9758C97  R9758C98  R9758C99
# R_l0_g9759  R9759C97  R9759C98  R9759C99
# R_l0_g9760  R9760C97  R9760C98  R9760C99
# R_l0_g9761  R9761C97  R9761C98  R9761C99
# R_l0_g9762  R9762C97  R9762C98  R9762C99
# R_l0_g9763  R9763C97  R9763C98  R9763C99
# R_l0_g9764  R9764C97  R9764C98  R9764C99
# R_l0_g9765  R9765C97  R9765C98  R9765C99
# R_l0_g9766  R9766C97  R9766C98  R9766C99
# R_l0_g9767  R9767C97  R9767C98  R9767C99
# R_l0_g9768  R9768C97  R9768C98  R9768C99
# R_l0_g9769  R9769C97  R9769C98  R9769C99
# R_l0_g9770  R9770C97  R9770C98  R9770C99
# R_l0_g9771  R9771C97  R9771C98  R9771C99
# R_l0_g9772  R9772C97  R9772C98  R9772C99
# R_l0_g9773  R9773C97  R9773C98  R9773C99
# R_l0_g9774  R9774C97  R9774C98  R9774C99
# R_l0_g9775  R9775C97  R9775C98  R9775C99
# R_l0_g9776  R9776C97  R9776C98  R9776C99
# R_l0_g9777  R9777C97  R9777C98  R9777C99
# R_l0_g9778  R9778C97  R9778C98  R9778C99
# R_l0_g9779  R9779C97  R9779C98  R9779C99
# R_l0_g9780  R9780C97  R9780C98  R9780C99
# R_l0_g9781  R9781C97  R9781C98  R9781C99
# R_l0_g9782  R9782C97  R9782C98  R9782C99
# R_l0_g9783  R9783C97  R9783C98  R9783C99
# R_l0_g9784  R9784C97  R9784C98  R9784C99
# R_l0_g9785  R9785C97  R9785C98  R9785C99
# R_l0_g9786  R9786C97  R9786C98  R9786C99
# R_l0_g9787  R9787C97  R9787C98  R9787C99
# R_l0_g9788  R9788C97  R9788C98  R9788C99
# R_l0_g9789  R9789C97  R9789C98  R9789C99
# R_l0_g9790  R9790C97  R9790C98  R9790C99
# R_l0_g9791  R9791C97  R9791C98  R9791C99
# R_l0_g9792  R9792C97  R9792C98  R9792C99
# R_l0_g9793  R9793C97  R9793C98  R9793C99
# R_l0_g9794  R9794C97  R9794C98  R9794C99
# R_l0_g9795  R9795C97  R9795C98  R9795C99
# R_l0_g9796  R9796C97  R9796C98  R9796C99
# R_l0_g9797  R9797C97  R9797C98  R9797C99
# R_l0_g9798  R9798C97  R9798C98  R9798C99
# R_l0_g9799  R9799C97  R9799C98  R9799C99
# R_l0_g9800  R9800C97  R9800C98  R9800C99
# R_l0_g9801  R9801C97  R9801C98  R9801C99
# R_l0_g9802  R9802C97  R9802C98  R9802C99
# R_l0_g9803  R9803C97  R9803C98  R9803C99
# R_l0_g9804  R9804C97  R9804C98  R9804C99
# R_l0_g9805  R9805C97  R9805C98  R9805C99
# R_l0_g9806  R9806C97  R9806C98  R9806C99
# R_l0_g9807  R9807C97  R9807C98  R9807C99
# R_l0_g9808  R9808C97  R9808C98  R9808C99
# R_l0_g9809  R9809C97  R9809C98  R9809C99
# R_l0_g9810  R9810C97  R9810C98  R9810C99
# R_l0_g9811  R9811C97  R9811C98  R9811C99
# R_l0_g9812  R9812C97  R9812C98  R9812C99
# R_l0_g9813  R9813C97  R9813C98  R9813C99
# R_l0_g9814  R9814C97  R9814C98  R9814C99
# R_l0_g9815  R9815C97  R9815C98  R9815C99
# R_l0_g9816  R9816C97  R9816C98  R9816C99
# R_l0_g9817  R9817C97  R9817C98  R9817C99
# R_l0_g9818  R9818C97  R9818C98  R9818C99
# R_l0_g9819  R9819C97  R9819C98  R9819C99
# R_l0_g9820  R9820C97  R9820C98  R9820C99
# R_l0_g9821  R9821C97  R9821C98  R9821C99
# R_l0_g9822  R9822C97  R9822C98  R9822C99
# R_l0_g9823  R9823C97  R9823C98  R9823C99
# R_l0_g9824  R9824C97  R9824C98  R9824C99
# R_l0_g9825  R9825C97  R9825C98  R9825C99
# R_l0_g9826  R9826C97  R9826C98  R9826C99
# R_l0_g9827  R9827C97  R9827C98  R9827C99
# R_l0_g9828  R9828C97  R9828C98  R9828C99
# R_l0_g9829  R9829C97  R9829C98  R9829C99
# R_l0_g9830  R9830C97  R9830C98  R9830C99
# R_l0_g9831  R9831C97  R9831C98  R9831C99
# R_l0_g9832  R9832C97  R9832C98  R9832C99
# R_l0_g9833  R9833C97  R9833C98  R9833C99
# R_l0_g9834  R9834C97  R9834C98  R9834C99
# R_l0_g9835  R9835C97  R9835C98  R9835C99
# R_l0_g9836  R9836C97  R9836C98  R9836C99
# R_l0_g9837  R9837C97  R9837C98  R9837C99
# R_l0_g9838  R9838C97  R9838C98  R9838C99
# R_l0_g9839  R9839C97  R9839C98  R9839C99
# R_l0_g9840  R9840C97  R9840C98  R9840C99
# R_l0_g9841  R9841C97  R9841C98  R9841C99
# R_l0_g9842  R9842C97  R9842C98  R9842C99
# R_l0_g9843  R9843C97  R9843C98  R9843C99
# R_l0_g9844  R9844C97  R9844C98  R9844C99
# R_l0_g9845  R9845C97  R9845C98  R9845C99
# R_l0_g9846  R9846C97  R9846C98  R9846C99
# R_l0_g9847  R9847C97  R9847C98  R9847C99
# R_l0_g9848  R9848C97  R9848C98  R9848C99
# R_l0_g9849  R9849C97  R9849C98  R9849C99
# R_l0_g9850  R9850C97  R9850C98  R9850C99
# R_l0_g9851  R9851C97  R9851C98  R9851C99
# R_l0_g9852  R9852C97  R9852C98  R9852C99
# R_l0_g9853  R9853C97  R9853C98  R9853C99
# R_l0_g9854  R9854C97  R9854C98  R9854C99
# R_l0_g9855  R9855C97  R9855C98  R9855C99
# R_l0_g9856  R9856C97  R9856C98  R9856C99
# R_l0_g9857  R9857C97  R9857C98  R9857C99
# R_l0_g9858  R9858C97  R9858C98  R9858C99
# R_l0_g9859  R9859C97  R9859C98  R9859C99
# R_l0_g9860  R9860C97  R9860C98  R9860C99
# R_l0_g9861  R9861C97  R9861C98  R9861C99
# R_l0_g9862  R9862C97  R9862C98  R9862C99
# R_l0_g9863  R9863C97  R9863C98  R9863C99
# R_l0_g9864  R9864C97  R9864C98  R9864C99
# R_l0_g9865  R9865C97  R9865C98  R9865C99
# R_l0_g9866  R9866C97  R9866C98  R9866C99
# R_l0_g9867  R9867C97  R9867C98  R9867C99
# R_l0_g9868  R9868C97  R9868C98  R9868C99
# R_l0_g9869  R9869C97  R9869C98  R9869C99
# R_l0_g9870  R9870C97  R9870C98  R9870C99
# R_l0_g9871  R9871C97  R9871C98  R9871C99
# R_l0_g9872  R9872C97  R9872C98  R9872C99
# R_l0_g9873  R9873C97  R9873C98  R9873C99
# R_l0_g9874  R9874C97  R9874C98  R9874C99
# R_l0_g9875  R9875C97  R9875C98  R9875C99
# R_l0_g9876  R9876C97  R9876C98  R9876C99
# R_l0_g9877  R9877C97  R9877C98  R9877C99
# R_l0_g9878  R9878C97  R9878C98  R9878C99
# R_l0_g9879  R9879C97  R9879C98  R9879C99
# R_l0_g9880  R9880C97  R9880C98  R9880C99
# R_l0_g9881  R9881C97  R9881C98  R9881C99
# R_l0_g9882  R9882C97  R9882C98  R9882C99
# R_l0_g9883  R9883C97  R9883C98  R9883C99
# R_l0_g9884  R9884C97  R9884C98  R9884C99
# R_l0_g9885  R9885C97  R9885C98  R9885C99
# R_l0_g9886  R9886C97  R9886C98  R9886C99
# R_l0_g9887  R9887C97  R9887C98  R9887C99
# R_l0_g9888  R9888C97  R9888C98  R9888C99
# R_l0_g9889  R9889C97  R9889C98  R9889C99
# R_l0_g9890  R9890C97  R9890C98  R9890C99
# R_l0_g9891  R9891C97  R9891C98  R9891C99
# R_l0_g9892  R9892C97  R9892C98  R9892C99
# R_l0_g9893  R9893C97  R9893C98  R9893C99
# R_l0_g9894  R9894C97  R9894C98  R9894C99
# R_l0_g9895  R9895C97  R9895C98  R9895C99
# R_l0_g9896  R9896C97  R9896C98  R9896C99
# R_l0_g9897  R9897C97  R9897C98  R9897C99
# R_l0_g9898  R9898C97  R9898C98  R9898C99
# R_l0_g9899  R9899C97  R9899C98  R9899C99
# R_l0_g9900  R9900C97  R9900C98  R9900C99
# R_l0_g9901  R9901C97  R9901C98  R9901C99
# R_l0_g9902  R9902C97  R9902C98  R9902C99
# R_l0_g9903  R9903C97  R9903C98  R9903C99
# R_l0_g9904  R9904C97  R9904C98  R9904C99
# R_l0_g9905  R9905C97  R9905C98  R9905C99
# R_l0_g9906  R9906C97  R9906C98  R9906C99
# R_l0_g9907  R9907C97  R9907C98  R9907C99
# R_l0_g9908  R9908C97  R9908C98  R9908C99
# R_l0_g9909  R9909C97  R9909C98  R9909C99
# R_l0_g9910  R9910C97  R9910C98  R9910C99
# R_l0_g9911  R9911C97  R9911C98  R9911C99
# R_l0_g9912  R9912C97  R9912C98  R9912C99
# R_l0_g9913  R9913C97  R9913C98  R9913C99
# R_l0_g9914  R9914C97  R9914C98  R9914C99
# R_l0_g9915  R9915C97  R9915C98  R9915C99
# R_l0_g9916  R9916C97  R9916C98  R9916C99
# R_l0_g9917  R9917C97  R9917C98  R9917C99
# R_l0_g9918  R9918C97  R9918C98  R9918C99
# R_l0_g9919  R9919C97  R9919C98  R9919C99
# R_l0_g9920  R9920C97  R9920C98  R9920C99
# R_l0_g9921  R9921C97  R9921C98  R9921C99
# R_l0_g9922  R9922C97  R9922C98  R9922C99
# R_l0_g9923  R9923C97  R9923C98  R9923C99
# R_l0_g9924  R9924C97  R9924C98  R9924C99
# R_l0_g9925  R9925C97  R9925C98  R9925C99
# R_l0_g9926  R9926C97  R9926C98  R9926C99
# R_l0_g9927  R9927C97  R9927C98  R9927C99
# R_l0_g9928  R9928C97  R9928C98  R9928C99
# R_l0_g9929  R9929C97  R9929C98  R9929C99
# R_l0_g9930  R9930C97  R9930C98  R9930C99
# R_l0_g9931  R9931C97  R9931C98  R9931C99
# R_l0_g9932  R9932C97  R9932C98  R9932C99
# R_l0_g9933  R9933C97  R9933C98  R9933C99
# R_l0_g9934  R9934C97  R9934C98  R9934C99
# R_l0_g9935  R9935C97  R9935C98  R9935C99
# R_l0_g9936  R9936C97  R9936C98  R9936C99
# R_l0_g9937  R9937C97  R9937C98  R9937C99
# R_l0_g9938  R9938C97  R9938C98  R9938C99
# R_l0_g9939  R9939C97  R9939C98  R9939C99
# R_l0_g9940  R9940C97  R9940C98  R9940C99
# R_l0_g9941  R9941C97  R9941C98  R9941C99
# R_l0_g9942  R9942C97  R9942C98  R9942C99
# R_l0_g9943  R9943C97  R9943C98  R9943C99
# R_l0_g9944  R9944C97  R9944C98  R9944C99
# R_l0_g9945  R9945C97  R9945C98  R9945C99
# R_l0_g9946  R9946C97  R9946C98  R9946C99
# R_l0_g9947  R9947C97  R9947C98  R9947C99
# R_l0_g9948  R9948C97  R9948C98  R9948C99
# R_l0_g9949  R9949C97  R9949C98  R9949C99
# R_l0_g9950  R9950C97  R9950C98  R9950C99
# R_l0_g9951  R9951C97  R9951C98  R9951C99
# R_l0_g9952  R9952C97  R9952C98  R9952C99
# R_l0_g9953  R9953C97  R9953C98  R9953C99
# R_l0_g9954  R9954C97  R9954C98  R9954C99
# R_l0_g9955  R9955C97  R9955C98  R9955C99
# R_l0_g9956  R9956C97  R9956C98  R9956C99
# R_l0_g9957  R9957C97  R9957C98  R9957C99
# R_l0_g9958  R9958C97  R9958C98  R9958C99
# R_l0_g9959  R9959C97  R9959C98  R9959C99
# R_l0_g9960  R9960C97  R9960C98  R9960C99
# R_l0_g9961  R9961C97  R9961C98  R9961C99
# R_l0_g9962  R9962C97  R9962C98  R9962C99
# R_l0_g9963  R9963C97  R9963C98  R9963C99
# R_l0_g9964  R9964C97  R9964C98  R9964C99
# R_l0_g9965  R9965C97  R9965C98  R9965C99
# R_l0_g9966  R9966C97  R9966C98  R9966C99
# R_l0_g9967  R9967C97  R9967C98  R9967C99
# R_l0_g9968  R9968C97  R9968C98  R9968C99
# R_l0_g9969  R9969C97  R9969C98  R9969C99
# R_l0_g9970  R9970C97  R9970C98  R9970C99
# R_l0_g9971  R9971C97  R9971C98  R9971C99
# R_l0_g9972  R9972C97  R9972C98  R9972C99
# R_l0_g9973  R9973C97  R9973C98  R9973C99
# R_l0_g9974  R9974C97  R9974C98  R9974C99
# R_l0_g9975  R9975C97  R9975C98  R9975C99
# R_l0_g9976  R9976C97  R9976C98  R9976C99
# R_l0_g9977  R9977C97  R9977C98  R9977C99
# R_l0_g9978  R9978C97  R9978C98  R9978C99
# R_l0_g9979  R9979C97  R9979C98  R9979C99
# R_l0_g9980  R9980C97  R9980C98  R9980C99
# R_l0_g9981  R9981C97  R9981C98  R9981C99
# R_l0_g9982  R9982C97  R9982C98  R9982C99
# R_l0_g9983  R9983C97  R9983C98  R9983C99
# R_l0_g9984  R9984C97  R9984C98  R9984C99
# R_l0_g9985  R9985C97  R9985C98  R9985C99
# R_l0_g9986  R9986C97  R9986C98  R9986C99
# R_l0_g9987  R9987C97  R9987C98  R9987C99
# R_l0_g9988  R9988C97  R9988C98  R9988C99
# R_l0_g9989  R9989C97  R9989C98  R9989C99
# R_l0_g9990  R9990C97  R9990C98  R9990C99
# R_l0_g9991  R9991C97  R9991C98  R9991C99
# R_l0_g9992  R9992C97  R9992C98  R9992C99
# R_l0_g9993  R9993C97  R9993C98  R9993C99
# R_l0_g9994  R9994C97  R9994C98  R9994C99
# R_l0_g9995  R9995C97  R9995C98  R9995C99
# R_l0_g9996  R9996C97  R9996C98  R9996C99
# R_l0_g9997  R9997C97  R9997C98  R9997C99
# R_l0_g9998  R9998C97  R9998C98  R9998C99
# R_l0_g9999  R9999C97  R9999C98  R9999C99
#
# [10000 rows x 100 columns]
